# %% [markdown]
# # First stetps in Neural Network with Keras

# %%
import numpy as np
import pandas as pd

# fix random seed for reproducibility
np.random.seed(8)

# %%
dataset = pd.read_csv("C:/Users/Mayer/Documents/DataScience/data/mtcars.csv")

# %% [markdown]
# For this example we will use the mtcars dataset.

# %%
# split into input (X) and output (Y) variables
nv = ["mpg","cyl","disp","hp","drat","wt","qsec","vs","gear","carb"]
X = np.array(dataset[nv])
y = np.array(dataset["am"])

# %% [markdown]
# ## Defining the Neural Network Architecture
#
# First we have to import in keras the <b>"Sequential"</b> function. This is the most common NN type, that means we are going to define our NN one layer a time. The other possible architecture available is the <b>"Functional"</b> function, which permits a more flexible architecture by letting join many structures in parallel.
#
# Then we initialize the NN by defining our model object and will add to it the layers as we defined in our network architecture plan.
#
# The layers that we will use are fully conected layers, which means that we want that all the input data from the previous layer will be connedted with all the nodes of this layer. In keras we call this layer type "Dense".
#
# When defining the layer we have to provide some parameters: input_dim is the dimmention of the input (in our case we have 10 inputs (variables) that enter our hidden layer.
#
# Another parameter is the activation function. We can define this function inside the layer definition, or separately (see alternatives 1 and 2).

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(12, input_dim=10, activation='relu'),
    Dense(1, activation='sigmoid')
])
# 12 = nodes, input dim= 10 inputs - number of colulms in X, the last layer is the output layer

# %%
# We will now create the NN architecture
#model = Sequential()
#model.add(Dense(12, input_dim=10))
#model.add(Activation('relu'))
#model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## Training the model
#
# To run our NN we have first to "compile" our model. The compilation require us to define some important parameters:
#
# 1. Define the <b>loss function</b>: this is the measure of the error. There are many types of loss functions that could be applied in NN's:
#  - mean_squared_error
#  - mean_absolute_error
#  - mean_absolute_percentage_error
#  - mean_squared_logarithmic_error
#  - squared_hinge
#  - hinge
#  - categorical_hinge
#  - logcosh
#  - categorical_crossentropy
#  - sparse_categorical_crossentropy
#  - binary_crossentropy
#  - kullback_leibler_divergence
#  - poisson - for ordinal feature
#  - cosine_proximity - for text or img
#
#
# 2. Define the <b>optimizer</b>: this is the method we want to apply for the gradient descent. Some popular methods are:
#  - Stochastic gradient descent (SGD) - for each row
#  - Adaptive moment estimator (Adam) - the favorite
#  - batch gradient descent - GD for the whole matrix
#  - mini-batch gradient descent
#  - Nesterov accelerated gradient (NAG)
#  - Adagrad
#  - AdaDelta
#  - RMSprop
#
#
# 3. Define the <b>metrics</b>: Metric values are recorded at the end of each epoch on the training dataset. The most common metrics are:
#  + For regression output:
#     - Mean Squared Error (MSE)
#     - Mean Absolute Error (MAE)
#     - Mean Absolute Percentage Error (MAPE)
#     - Cosine Proximity
#
#  + For classification output:
#     - Binary Accuracy
#     - Categorical Accuracy
#     - Sparse Categorical Accuracy
#     - Top k Categorical Accuracy
#     - Sparse Top k Categorical Accuracy

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# After compilation, the model could be trained. We use the fit function to begin the training.

# %%
# Fit the model
res = model.fit(X, y, epochs=150, batch_size=10)
#epochs= iteration number- how much time we go forward and backward, batch_size=10 - number orf rows checked 10-20,20-30..
# Out:
# Epoch 1/150
# 32/32 [==============================] - 0s 14ms/step - loss: 0.
150
# 32/32 [==============================] - 0s 312us/step - loss: 0.1212 - acc: 0.8750
# Epoch 139/150
# 32/32 [==============================] - 0s 375us/step - loss: 0.1212 - acc: 0.8750
# Epoch 140/150
# 32/32 [==============================] - 0s 406us/step - loss: 0.1213 - acc: 0.8750
# Epoch 141/150
# 32/32 [==============================] - 0s 406us/step - loss: 0.1213 - acc: 0.8750
# Epoch 142/150
# 32/32 [==============================] - 0s 250us/step - loss: 0.1214 - acc: 0.8750
# Epoch 143/150
# 32/32 [==============================] - 0s 312us/step - loss: 0.1212 - acc: 0.8750
# Epoch 144/150
# 32/32 [==============================] - 0s 687us/step - loss: 0.1219 - acc: 0.8750
# Epoch 145/150
# 32/32 [==============================] - 0s 281us/step - loss: 0.1219 - acc: 0.8750
# Epoch 146/150
# 32/32 [==============================] - 0s 250us/step - loss: 0.1217 - acc: 0.8750
# Epoch 147/150
# 32/32 [==============================] - 0s 344us/step - loss: 0.1217 - acc: 0.8750
# Epoch 148/150
# 32/32 [==============================] - 0s 283us/step - loss: 0.1215 - acc: 0.8750
# Epoch 149/150
# 32/32 [==============================] - 0s 598us/step - loss: 0.1208 - acc: 0.8750
# Epoch 150/150
# 32/32 [==============================] - 0s 219us/step - loss: 0.1211 - acc: 0.8750

# %%
res.history['loss']
# Out:
# [0.4062498053535819,
#  0.4062490910291672,
#  0.40624178666621447,
#  0.40620621480047703,
#  0.40560116060078144,
#  0.4028221443295479,
#  0.37705316953361034,
#  0.3435893729329109,
#  0.34321215422824025,
#  0.34190728794783354,
#  0.33604199439287186,
#  0.3194228298962116,
#  0.3114617709070444,
#  0.3004961861297488,
#  0.2812339293304831,
#  0.2566175484098494,
#  0.2388605475518853,
#  0.23932428052648902,
#  0.2310794424265623,
#  0.2507262169383466,
#  0.255378752714023,
#  0.21444163750857115,
#  0.18939797843884776,
#  0.19050108781084418,
#  0.19502714132977417,
#  0.1808157521809335,
#  0.18286663461731223,
#  0.17794728405112892,
#  0.176253211684525,
#  0.16992043145000935,
#  0.16975564277345256,
#  0.16843818388224463,
#  0.16767639032696025,
#  0.17303907964378595,
#  0.1778873661532998,
#  0.1867358759045601,
#  0.18866566475480795,
#  0.18486782163381577,
#  0.17706725094467402,
#  0.1780223186360672,
#  0.17457122448831797,
#  0.17251720768399537,
#  0.1675634659469658,
#  0.16442619477392562,
#  0.1559452130459249,
#  0.16235992452129722,
#  0.17499760859618618,
#  0.1833024569787085,
#  0.17240956611931324,
#  0.16170320473611355,
#  0.1518466943106347,
#  0.15095457853749394,
#  0.1504870019853115,
#  0.13941630784756853,
#  0.15073613938875496,
#  0.1529526450690355,
#  0.15027255875088485,
#  0.14033400510470528,
#  0.13334210542961955,
#  0.1279343117494136,
#  0.13071520029916428,
#  0.130689813607205,
#  0.12662615624395812,
#  0.12554242787882686,
#  0.12803872348740697,
#  0.12945863918866962,
#  0.1315520405990771,
#  0.12847378151491284,
#  0.1250111373159939,
#  0.12458307690394577,
#  0.12583721242845058,
#  0.12380010361089155,
#  0.1245581690870683,
#  0.12656840605643993,
#  0.12545447394950315,
#  0.1253474240656942,
#  0.1236390127451159,
#  0.12384663103148341,
#  0.12412987156892541,
#  0.1238916136790067,
#  0.12312497339189576,
#  0.12489832937717438,
#  0.1245453188216743,
#  0.1245046051335521,
#  0.124619262432347,
#  0.12538576775114052,
#  0.12470983677297909,
#  0.1244059684977401,
#  0.12359205959364772,
#  0.1240992165330681,
#  0.12391867602823936,
#  0.1234587227691577,
#  0.12315062133501442,
#  0.12317321295267902,
#  0.12318587955087423,
#  0.12329971122926509,
#  0.12350440584123135,
#  0.12284034373111297,
#  0.12334705017011949,
#  0.12390962075141942,
#  0.12394982484693173,
#  0.1232628272700822,
#  0.123549432028085,
#  0.12343736263574101,
#  0.12323583614488598,
#  0.12285057884582784,
#  0.1228254753406155,
#  0.12265104900505008,
#  0.12259381243347889,
#  0.12265598498842512,
#  0.12284112710040063,
#  0.12331642852191216,
#  0.12502396130003035,
#  0.1253814442170551,
#  0.12346392282574925,
#  0.12018412275908663,
#  0.12485818645353852,
#  0.12759059352566737,
#  0.12423762193066068,
#  0.12253147782757878,
#  0.12201794074059436,
#  0.12280645001737867,
#  0.12288765558561998,
#  0.12290989455414092,
#  0.12238080147653818,
#  0.122077691485174,
#  0.12215662398375571,
#  0.12444385152775794,
#  0.12308446900823844,
#  0.12364489451283589,
#  0.1239121011167299,
#  0.12467488859329023,
#  0.12974441749975085,
#  0.12583313904178794,
#  0.1270600768039003,
#  0.12519092121428343,
#  0.1228189121505352,
#  0.12121903503190268,
#  0.12116836777749995,
#  0.1212947782187257,
#  0.12127195282391767,
#  0.12142298734397627,
#  0.12121376965296804,
#  0.12185159847170546,
#  0.12187137577711837,
#  0.12171128572825296,
#  0.12167405983120716,
#  0.12149771107942797,
#  0.12084486921685311,
#  0.12106059867073782]

# %% [markdown]
# We now will check the performance of the model by comparing the prediction (yhat) with the original label (y)

# %%
# evaluate the model
scores = model.evaluate(X, y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 32/32 [==============================] - 0s 3ms/step
#
# acc: 87.50%

# %% [markdown]
# ## Predicting using the model
#
# We can then use the predict function to run the trained model on a new (test) dataset:

# %%
# calculate predictions
predictions = model.predict(X)
# round predictions
rounded = [round(x[0]) for x in predictions]
#print(rounded)

# %%
print(pd.DataFrame({'yhat':rounded,'y':y}))
# Out:
#     y  yhat
# 0   1   0.0
# 1   1   0.0
# 2   1   1.0
# 3   0   0.0
# 4   0   0.0
# 5   0   0.0
# 6   0   0.0
# 7   0   0.0
# 8   0   0.0
# 9   0   0.0
# 10  0   0.0
# 11  0   0.0
# 12  0   0.0
# 13  0   0.0
# 14  0   0.0
# 15  0   0.0
# 16  0   0.0
# 17  1   1.0
# 18  1   1.0
# 19  1   1.0
# 20  0   1.0
# 21  0   0.0
# 22  0   0.0
# 23  0   0.0
# 24  0   0.0
# 25  1   1.0
# 26  1   1.0
# 27  1   1.0
# 28  1   1.0
# 29  1   1.0
# 30  1   1.0
# 31  1   1.0

# %% [markdown]
# <iframe src="/assets/conv-demo/index.html" width="100%" height="700px;" style="border:none;"></iframe>
