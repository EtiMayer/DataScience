# %% [markdown]
# ## Activism Cluster Analysis

# %%
### Data
df <- read.csv('C:/Users/Mayer/Documents/DataScience/She Code/Global Activism/SC_FinalFiles/ActivismCleanFile.csv')
head(df)
# Out:
#   Investor.ID Activist                      ActivistHQ ActivistRegion Founded
# 1  2          Aberdeen Asset Management PLC 64         WestEurope     1983
# 2  2          Aberdeen Asset Management PLC 64         WestEurope     1983
# 3  2          Aberdeen Asset Management PLC 64         WestEurope     1983
# 4  2          Aberdeen Asset Management PLC 64         WestEurope     1983
# 5 14          AFL-CIO                       68         NorthAmerica   miss
# 6 14          AFL-CIO                       68         NorthAmerica   miss
#   FirstDateInvestedByActivisit CurrentHolding StatusCurrent StatusExisted
# 1 17169                        miss           1             0
# 2 14862                        1              1             0
# 3 16695                        miss           0             1
# 4 15932                        miss           1             0
# 5 15789                        miss           1             0
# 6 16854                        miss           1             0
#   DateExited ... SeatsGainedMethod Ongoing WithdrewDemands PartiallySuccessful
# 1 miss       ... miss              No      No              No
# 2 miss       ... miss              No      No              No
# 3 2016       ... miss              No      No              No
# 4 miss       ... miss              No      No              No
# 5 miss       ... miss              No      No              No
# 6 miss       ... miss              No      No              No
#   Successful Unsuccessful CompromiseOrSettlement Unresolved Buyer Succession
# 1 No         Yes          No                     No         miss  0
# 2 Yes        No           No                     No         miss  0
# 3 Yes        No           No                     No         8     1
# 4 No         No           No                     No         miss  0
# 5 No         Yes          No                     No         miss  0
# 6 No         Yes          No                     No         miss  0

# %%
summary(df)
# Out:
#   Investor.ID                        Activist      ActivistHQ
#  Min.   :    2   Bulldog Investors       : 275   68     :6483
#  1st Qu.: 5087   Third Point Partners    : 253   64     : 594
#  Median : 5760   Elliott Management      : 162   3      : 514
#  Mean   : 5542   Starboard Value         : 157   32     : 283
#  3rd Qu.: 6621   Taconic Capital Advisors: 138   11     : 273
#  Max.   :11059   Stilwell Value LLC      : 137   25     : 126
#                  (Other)                 :8177   (Other):1026
#         ActivistRegion    Founded     FirstDateInvestedByActivisit
#  AustraliaNZ   : 568   miss   :1963   16205  : 167
#  FarEast       : 588   2005   : 462   17120  : 113
#  NorthAmerica  :6795   1992   : 417   16937  : 112
#  RestOfTheWorld: 198   1995   : 409   18307  : 105
#  WestEurope    :1150   2012   : 329   17485  : 103
#                        1999   : 317   16570  :  94
#                        (Other):5402   (Other):8605
#  CurrentHolding StatusCurrent   StatusExisted     DateExited      ExitType
#  0    : 616     Min.   :0.000   Min.   :0.000   miss   :4529   miss   :4531
#  1    : 631     1st Qu.:0.000   1st Qu.:0.000   2016   : 686   15     :2922
#  23.04: 649     Median :0.000   Median :1.000   2018   : 670   12     : 739
#  4.7  : 607     Mean   :0.487   Mean   :0.513   2017   : 663   13     : 227
#  8.89 : 645     3rd Qu.:1.000   3rd Qu.:1.000   2019   : 658   6      : 207
#  miss :6151     Max.   :1.000   Max.   :1.000   2015   : 522   14     : 190
#                                                 (Other):1571   (Other): 483
#                   Company          PID          PID_COUNT     CompanyHQ
#  Danske Bank A/S      :  16   Min.   :    1   Min.   :1   US       :5761
#  Altaba Inc.          :  14   1st Qu.: 2002   1st Qu.:1   UK       : 632
#  Deutsche Bank AG     :  14   Median : 6607   Median :1   Australia: 606
#  Optiscan Imaging Ltd :  13   Mean   :14054   Mean   :1   Japan    : 473
#  Caravel Minerals Ltd.:  12   3rd Qu.:26522   3rd Qu.:1   Canada   : 468
#  Facebook Inc.        :  12   Max.   :49460   Max.   :1   Germany  : 165
#  (Other)              :9218                               (Other)  :1194
#         ConpanyRegion     Currency    FR_PriceStart   FR_PriceEnd
#  FarEast       : 732   10     :6349   miss   :1114   miss   :1181
#  NorthAmerica  :6285   miss   :2850   0.01   :  62   0.01   : 130
#  RestOfTheWorld: 917   4      :  33   0.03   :  58   0      : 116
#  WestEurope    :1365   1      :  18   0.07   :  53   0.03   :  85
#                        2      :  15   0.02   :  39   0.02   :  71
#                        7      :  10   0.06   :  35   0.1    :  64
#                        (Other):  24   (Other):7938   (Other):7652
#     PriceChangeSinceExitByCamp SPChangeSinceExitByCamp
#  miss            :5517         miss   :5972
#  -100            : 355         24.62  : 320
#  -3.946          : 355         47.974 : 318
#  1.98800000000001: 351         -24.51 : 311
#  79.179          : 350         31.45  : 308
#  -85.326         : 347         170.94 : 305
#  (Other)         :2024         (Other):1765
#   AvgChangeOverPeriodOfInvByAct AvgReturnAnnualisedByAct AvgSPReturnByAct
#  miss            :3196          miss   :3344             miss   :2688
#  2.494031557565  : 560          18.69  : 548             30.21  : 275
#  4.05379871196251: 560          -1.89  : 545             17.35  : 253
#  2.15755932094379: 559          15.07  : 544             36.43  : 162
#  3.82209829790016: 559          8.53   : 543             17.44  : 157
#  2.88870370079547: 557          38.66  : 542             12.05  : 138
#  (Other)         :3308          (Other):3233             (Other):5626
#  AvgSPReturnAnnualisedByAct          ExcessReturnByAct    LastInv
#  miss   :2791               miss              :3241    18307  : 963
#  14.43  : 320               5.83              : 559    18359  : 289
#  15.54  : 287               -23.38            : 554    18330  : 260
#  11.86  : 262               -0.759999999999998: 553    18215  : 229
#  15.28  : 253               -47.83            : 552    18351  : 210
#  16.15  : 138               11.61             : 552    18449  : 163
#  (Other):5248               (Other)           :3288    (Other):7185
#   ReturnByCamp  ReturnAnnualisedByCamp SPChangeByCamp SPChangeAnnualisedByCamp
#  miss   : 776   miss   : 962           miss   : 896   miss   :1843
#  0      :  40   0      :  40           0.33   : 105   15.98  :  49
#  -30.77 :  11   -14.07 :  11           9.2    :  52   12.68  :  48
#  -5.56  :  10   -32.54 :  10           27.36  :  39   14.94  :  42
#  -16.67 :   9   1.73   :   9           20.25  :  37   12.08  :  41
#  -92.59 :   9   4.96   :   9           10.12  :  35   13.01  :  40
#  (Other):8444   (Other):8258           (Other):8135   (Other):7236
#     NoOfCamp    PositiveReturnByCamp ExcessReturnByCamp  HitRatioByAct
#  1      :2020   0      :2109         miss   : 998       0       :2109
#  miss   : 528   1      :1110         -57.2  :  11       miss    : 515
#  2      : 484   miss   : 685         -7.92  :   9       0.5     : 400
#  3      : 327   2      : 568         -145.31:   8       0.333333: 345
#  4      : 288   3      : 329         -114.03:   7       0.378181: 275
#  5      : 235   13     : 303         -29.28 :   7       0.25    : 260
#  (Other):5417   (Other):4195         (Other):8259       (Other) :5395
#    NoOfCamp3Y   PositiveReturnByCamp3Y HitRatioByAct3Y     Industry
#  0      :3265   0      :4727           Min.   :0.0000   58     : 400
#  1      :1437   miss   :1434           1st Qu.:0.0000   132    : 383
#  miss   :1011   1      :1066           Median :0.0000   27     : 302
#  2      : 581   2      : 462           Mean   :0.2261   94     : 294
#  3      : 351   3      : 428           3rd Qu.:0.4242   22     : 286
#  7      : 336   5      : 395           Max.   :1.0000   18     : 285
#  (Other):2318   (Other): 787                            (Other):7349
#      Sector       CampByIND    PositiveReturnByIND HitRatioByIND    CampByIND3Y
#  12     :1515   1      :3252   0      :3317        Min.   :0.0000   0   :4592
#  3      :1403   miss   :1268   1      :1950        1st Qu.:0.0000   1   :1772
#  9      :1262   2      : 946   miss   :1138        Median :0.3333   2   : 640
#  6      :1144   3      : 624   2      : 811        Mean   :0.3306   3   : 499
#  8      : 894   4      : 504   3      : 494        3rd Qu.:0.5000   4   : 249
#  1      : 853   5      : 370   4      : 372        Max.   :1.0000   5   : 103
#  (Other):2228   (Other):2335   (Other):1217                         miss:1444
#  PositiveReturnByIND3Y HitRatioByIND3Y  NoOfInvByIND
#  0   :6212             0       :6212   2244   :1951
#  1   :1249             miss    : 727   2045   :1917
#  2   : 599             0.5     : 549   1539   :1216
#  miss:1239             0.333333: 193   1311   :1190
#                        0.666666: 189   1469   :1060
#                        0.166666: 180   1217   :1015
#                        (Other) :1249   (Other): 950
#  AvgChangeOverPeriodOfInvByIND     AvgReturnAnnualisedByIND AvgSPReturnByIND
#  58.61  :1951                  1.81482474215905:1459        45.99  :1951
#  49.7   :1917                  1.96290772542388: 482        52.44  :1917
#  34.49  :1216                  2.12465388450138:1920        40.48  :1216
#  26.18  :1190                  2.56648663678042:1364        56.39  :1190
#  65.02  :1060                  miss            :4074        39.58  :1060
#  29.07  :1015                                               49.66  :1015
#  (Other): 950                                               (Other): 950
#  AvgSPReturnAnnualisedByIND   MarketCap    MarketCapCategory    CampByMC
#  13.65:1216                 miss   :1596   Large-Cap:  24    1      :2155
#  13.82:1015                 0      : 114   Mid-Cap  : 145    miss   : 841
#  13.9 :1190                 1      : 113   Nano-Cap :8329    2      : 572
#  13.91:1951                 3      : 103   Small-Cap: 801    3      : 333
#  14.1 :1917                 4      :  93                     4      : 304
#  14.38:1060                 6      :  88                     5      : 235
#  miss : 950                 (Other):7192                     (Other):4859
#  PositiveReturnByMC     HitRatioByMC    CampByMC3Y   PositiveReturnByMC3Y
#  0      :2227       0         :2227   0      :3423   0      :4968
#  1      :1197       miss      : 603   1      :1588   1      :1088
#  miss   :1141       0.5       : 530   miss   :1131   miss   : 944
#  2      : 590       0.25      : 320   2      : 546   2      : 470
#  3      : 375       0.33333333: 282   3      : 345   3      : 437
#  6      : 301       0.36900369: 271   7      : 253   4      : 371
#  (Other):3468       (Other)   :5066   (Other):2013   (Other):1021
#  HitRatioByMC3Y    NoOfInvByMC    AvgChangeOverPeriodOfInvByMC AvgSPReturnByMC
#  Min.   :0.0000   Min.   :7.460   Min.   :1.320                Min.   :3.736
#  1st Qu.:0.0000   1st Qu.:7.641   1st Qu.:1.510                1st Qu.:4.078
#  Median :0.0000   Median :7.641   Median :1.510                Median :4.078
#  Mean   :0.2160   Mean   :7.672   Mean   :1.501                Mean   :4.044
#  3rd Qu.:0.4074   3rd Qu.:7.641   3rd Qu.:1.510                3rd Qu.:4.078
#  Max.   :1.0000   Max.   :8.025   Max.   :1.510                Max.   :4.078
#
#  ConcernedShareholder   Engagement       Occasional      PartialFocus
#  Min.   :0.0000       Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000       1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :0.0000       Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.1048       Mean   :0.1014   Mean   :0.1774   Mean   :0.2337
#  3rd Qu.:0.0000       3rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:0.0000
#  Max.   :1.0000       Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#   PrimaryFocus     ActivistAUM   ActivistAUMDate      Long
#  Min.   :0.0000   miss   :3553   miss   :2850    Min.   :1
#  1st Qu.:0.0000   6351   : 534   18351  :1151    1st Qu.:1
#  Median :0.0000   110    : 526   18348  : 386    Median :1
#  Mean   :0.3819   1005.5 : 525   18438  : 353    Mean   :1
#  3rd Qu.:1.0000   2883   : 525   18431  : 349    3rd Qu.:1
#  Max.   :1.0000   12343  : 524   18261  : 307    Max.   :1
#                   (Other):3112   (Other):3903
#  GainBoardRepresentation AdoptMajorityVoteStandard   AmendByLaw
#  Min.   :0.0000          Min.   :0.00000           Min.   :0.00000
#  1st Qu.:0.0000          1st Qu.:0.00000           1st Qu.:0.00000
#  Median :0.0000          Median :0.00000           Median :0.00000
#  Mean   :0.2887          Mean   :0.01914           Mean   :0.06807
#  3rd Qu.:1.0000          3rd Qu.:0.00000           3rd Qu.:0.00000
#  Max.   :1.0000          Max.   :1.00000           Max.   :1.00000
#
#  AmendListingStatus BoardIndependence BusinessFocus     BusinessRestructuring
#  Min.   :0.000000   Min.   :0.00000   Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.000000   Median :0.00000   Median :0.00000   Median :0.000000
#  Mean   :0.001828   Mean   :0.02463   Mean   :0.01678   Mean   :0.007097
#  3rd Qu.:0.000000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.000000   Max.   :1.00000   Max.   :1.00000   Max.   :1.000000
#
#  ChangeBoardComposition ClosureOfBusinessUnit   Dividends
#  Min.   :0.00000        Min.   :0.0000000     Min.   :0.00000
#  1st Qu.:0.00000        1st Qu.:0.0000000     1st Qu.:0.00000
#  Median :0.00000        Median :0.0000000     Median :0.00000
#  Mean   :0.03732        Mean   :0.0007528     Mean   :0.02237
#  3rd Qu.:0.00000        3rd Qu.:0.0000000     3rd Qu.:0.00000
#  Max.   :1.00000        Max.   :1.0000000     Max.   :1.00000
#
#  EliminateStaggeredBoard EquityIssuance       ExcessCash
#  Min.   :0.00000         Min.   :0.000000   Min.   :0.000000
#  1st Qu.:0.00000         1st Qu.:0.000000   1st Qu.:0.000000
#  Median :0.00000         Median :0.000000   Median :0.000000
#  Mean   :0.01645         Mean   :0.002903   Mean   :0.001828
#  3rd Qu.:0.00000         3rd Qu.:0.000000   3rd Qu.:0.000000
#  Max.   :1.00000         Max.   :1.000000   Max.   :1.000000
#
#  FocusOnGrowthStrategies GeneralCostCutting
#  Min.   :0.000000        Min.   :0.0000
#  1st Qu.:0.000000        1st Qu.:0.0000
#  Median :0.000000        Median :0.0000
#  Mean   :0.007097        Mean   :0.0171
#  3rd Qu.:0.000000        3rd Qu.:0.0000
#  Max.   :1.000000        Max.   :1.0000
#
#  LackOfInaccurateInformationFromCompany OperationalEfficiency
#  Min.   :0.00000                        Min.   :0.00000
#  1st Qu.:0.00000                        1st Qu.:0.00000
#  Median :0.00000                        Median :0.00000
#  Mean   :0.03011                        Mean   :0.01129
#  3rd Qu.:0.00000                        3rd Qu.:0.00000
#  Max.   :1.00000                        Max.   :1.00000
#
#  OpposeAcquisitionOfThirdParty OpposeEquityIssuance OpposeProxyContest
#  Min.   :0.00000               Min.   :0.000000     Min.   :0
#  1st Qu.:0.00000               1st Qu.:0.000000     1st Qu.:0
#  Median :0.00000               Median :0.000000     Median :0
#  Mean   :0.01097               Mean   :0.008818     Mean   :0
#  3rd Qu.:0.00000               3rd Qu.:0.000000     3rd Qu.:0
#  Max.   :1.00000               Max.   :1.000000     Max.   :0
#
#  OpposeSaleOfCompany PushForAcquisitionOfThirdParty PushForCompanyDivision
#  Min.   :0.00000     Min.   :0.000000               Min.   :0.000000
#  1st Qu.:0.00000     1st Qu.:0.000000               1st Qu.:0.000000
#  Median :0.00000     Median :0.000000               Median :0.000000
#  Mean   :0.03495     Mean   :0.002473               Mean   :0.003871
#  3rd Qu.:0.00000     3rd Qu.:0.000000               3rd Qu.:0.000000
#  Max.   :1.00000     Max.   :1.000000               Max.   :1.000000
#
#  PushForSaleOfCompany PushForOpposeMergingOfShares Recapitalization
#  Min.   :0.00000      Min.   :0.000000             Min.   :0.000000
#  1st Qu.:0.00000      1st Qu.:0.000000             1st Qu.:0.000000
#  Median :0.00000      Median :0.000000             Median :0.000000
#  Mean   :0.08302      Mean   :0.003656             Mean   :0.002581
#  3rd Qu.:0.00000      3rd Qu.:0.000000             3rd Qu.:0.000000
#  Max.   :1.00000      Max.   :1.000000             Max.   :1.000000
#
#  RedemptionAmendmentOfPoisonPill REITorMLPConversion
#  Min.   :0.000000                Min.   :0.000000
#  1st Qu.:0.000000                1st Qu.:0.000000
#  Median :0.000000                Median :0.000000
#  Mean   :0.006775                Mean   :0.002473
#  3rd Qu.:0.000000                3rd Qu.:0.000000
#  Max.   :1.000000                Max.   :1.000000
#
#  RemovalOfCEOorOtherBoardMember  Remuneration     ReplaceAuditor
#  Min.   :0.0000                 Min.   :0.00000   Min.   :0.000000
#  1st Qu.:0.0000                 1st Qu.:0.00000   1st Qu.:0.000000
#  Median :0.0000                 Median :0.00000   Median :0.000000
#  Mean   :0.1315                 Mean   :0.04431   Mean   :0.003011
#  3rd Qu.:0.0000                 3rd Qu.:0.00000   3rd Qu.:0.000000
#  Max.   :1.0000                 Max.   :1.00000   Max.   :1.000000
#
#  ReplaceManagement  RestructureDebt    ReturnCashToShareholders
#  Min.   :0.000000   Min.   :0.000000   Min.   :0.00000
#  1st Qu.:0.000000   1st Qu.:0.000000   1st Qu.:0.00000
#  Median :0.000000   Median :0.000000   Median :0.00000
#  Mean   :0.008711   Mean   :0.004301   Mean   :0.00828
#  3rd Qu.:0.000000   3rd Qu.:0.000000   3rd Qu.:0.00000
#  Max.   :1.000000   Max.   :1.000000   Max.   :1.00000
#
#  SellOrRetainAssets SeparateChairmanAndCEO ShareRepurchase
#  Min.   :0.00000    Min.   :0.000000       Min.   :0.00000
#  1st Qu.:0.00000    1st Qu.:0.000000       1st Qu.:0.00000
#  Median :0.00000    Median :0.000000       Median :0.00000
#  Mean   :0.02473    Mean   :0.008388       Mean   :0.03678
#  3rd Qu.:0.00000    3rd Qu.:0.000000       3rd Qu.:0.00000
#  Max.   :1.00000    Max.   :1.000000       Max.   :1.00000
#
#  SpinOffSaleOfBusinessDivision SuccessionPlanning
#  Min.   :0.00000               Min.   :0.0000000
#  1st Qu.:0.00000               1st Qu.:0.0000000
#  Median :0.00000               Median :0.0000000
#  Mean   :0.02183               Mean   :0.0004302
#  3rd Qu.:0.00000               3rd Qu.:0.0000000
#  Max.   :1.00000               Max.   :1.0000000
#
#  TerminateInvestmentAdvisoryAgreement UnderLeverage       UseUniversalBallot
#  Min.   :0.000000                     Min.   :0.0000000   Min.   :0.0000000
#  1st Qu.:0.000000                     1st Qu.:0.0000000   1st Qu.:0.0000000
#  Median :0.000000                     Median :0.0000000   Median :0.0000000
#  Mean   :0.007635                     Mean   :0.0006452   Mean   :0.0003226
#  3rd Qu.:0.000000                     3rd Qu.:0.0000000   3rd Qu.:0.0000000
#  Max.   :1.000000                     Max.   :1.0000000   Max.   :1.0000000
#
#    AGM       ActivistWithdrewDemands   NA.       AGMResult   MergerCompleted
#  1   :8125   1   :9018               1   :6978   1   :9087   1   :9252
#  2   :1167   2   : 274               2   :2314   2   : 205   2   :  40
#  miss:   7   miss:   7               miss:   7   miss:   7   miss:   7
#
#
#
#
#  EGMorSpecialMeeting ProxyContest ActivistExitsStock MergerOrTakeover
#  1   :9017           1   :8211    1   :9144          1   :8932
#  2   : 275           2   :1081    2   : 148          2   : 360
#  miss:   7           miss:   7    miss:   7          miss:   7
#
#
#
#
#  MetWithDemandsInFull PublicDisagreement NoPublicResponse CompromiseOrAgreement
#  1   :8837            1   :9215          1   :8893        1   :9027
#  2   : 455            2   :  77          2   : 399        2   : 265
#  miss:   7            miss:   7          miss:   7        miss:   7
#
#
#
#
#  ShareholderVote CompanyHiresFiresResignations ActivistHiresFiresResignations
#  1   :9162       1   :8996                     1   :9290
#  2   : 130       2   : 296                     2   :   2
#  miss:   7       miss:   7                     miss:   7
#
#
#
#
#  EngagedActivistPositively NewCEOAppointed CompanyRejectsTakeoverBid
#  1   :9161                 1   :9287       1   :9225
#  2   : 131                 2   :   5       2   :  67
#  miss:   7                 miss:   7       miss:   7
#
#
#
#
#  CompanyRejectsSpecialMeeting MeetingsWithBoardOrManagement
#  1   :9263                    1   :9272
#  2   :  29                    2   :  20
#  miss:   7                    miss:   7
#
#
#
#
#  ActivistWritesToRegulator CommunicationWithShareholders WentToVote
#  1   :9288                 1   :9276                     1   :9239
#  2   :   4                 2   :  16                     2   :  53
#  miss:   7                 miss:   7                     miss:   7
#
#
#
#
#  JobCuts     ExternalAdvice CEOorChairmanDeparts
#  1   :9283   1   :9285      1   :9289
#  2   :   9   2   :   7      2   :   3
#  miss:   7   miss:   7      miss:   7
#
#
#
#
#  ActivistAppealsToRegulatorOrCourts Lawsuit     CR_Dividends
#  1   :9284                          1   :9270   1   :9265
#  2   :   8                          2   :  22   2   :  27
#  miss:   7                          miss:   7   miss:   7
#
#
#
#
#  DividendOrShareRepurchaseChange CompanyMakesAcquisition
#  1   :9278                       1   :9268
#  2   :  14                       2   :  24
#  miss:   7                       miss:   7
#
#
#
#
#  CompanyReleasesFinancials WelcomedActivist Bankruptcy  ProxyAccess
#  1   :9283                 1   :9275        1   :9288   1   :9288
#  2   :   9                 2   :  17        2   :   4   2   :   4
#  miss:   7                 miss:   7        miss:   7   miss:   7
#
#
#
#
#  ImplementAmendPoisonPill ActivistWinsBoardSeats ActivistNominatesBoardMembers
#  1   :9271                1   :9272              1   :9289
#  2   :  21                2   :  20              2   :   3
#  miss:   7                miss:   7              miss:   7
#
#
#
#
#  ThankedActivist ShareholderProposal TenderOffer
#  1   :9287       1   :9286           1   :9275
#  2   :   5       2   :   6           2   :  17
#  miss:   7       miss:   7           miss:   7
#
#
#
#
#  ActivistDropsBelowReportingThreshold NewMergerAnnounced ProxyAdvisorVerdict
#  1   :9291                            1   :9287          1   :9291
#  2   :   1                            2   :   5          2   :   1
#  miss:   7                            miss:   7          miss:   7
#
#
#
#
#  ActivistStatement PoisonPillImplemented LawsuitAgainstActivist
#  1   :9289         1   :9291             1   :9287
#  2   :   3         2   :   1             2   :   5
#  miss:   7         miss:   7             miss:   7
#
#
#
#
#  LetterToFellowShareholders ActivistNomineesAppointedToBoard
#  1   :9285                  1   :9289
#  2   :   7                  2   :   3
#  miss:   7                  miss:   7
#
#
#
#
#  SettlementAgreementConcluded LetterToBoardOrManagement
#  1   :9280                    1   :9289
#  2   :  12                    2   :   3
#  miss:   7                    miss:   7
#
#
#
#
#  CompanyRejectsBoardNominations DelayShareholderMeeting CloseFund   ClosedAGM
#  1   :9291                      1   :9289               1   :9289   1   :9291
#  2   :   1                      2   :   3               2   :   3   2   :   1
#  miss:   7                      miss:   7               miss:   7   miss:   7
#
#
#
#
#  ActivistIssuesPublicLetter ActivistLetterToRegulatoryBodies
#  1   :9291                  1   :9291
#  2   :   1                  2   :   1
#  miss:   7                  miss:   7
#
#
#
#
#  LitigationInitiated ConsentSolicitationInitiated SECFiling   SeatsProposed
#  1   :9291           1   :9290                    1   :9291   miss   :6751
#  2   :   1           2   :   2                    2   :   1   1      : 849
#  miss:   7           miss:   7                    miss:   7   2      : 657
#                                                               3      : 518
#                                                               4      : 241
#                                                               5      : 157
#                                                               (Other): 126
#  SeatsGained SeatsGainedMethod Ongoing    WithdrewDemands PartiallySuccessful
#  0   : 913   2   :1281         No :8907   No :8473        No :8687
#  1   : 770   3   : 891         Yes: 392   Yes: 826        Yes: 612
#  2   : 498   miss:7127
#  3   : 259
#  4   :  95
#  5   :  39
#  miss:6725
#  Successful Unsuccessful CompromiseOrSettlement Unresolved     Buyer
#  No :6659   No :7055     No :9164               No :9041   miss   :7866
#  Yes:2640   Yes:2244     Yes: 135               Yes: 258   820    :  13
#                                                            13     :  12
#                                                            64     :  12
#                                                            629    :   9
#                                                            875    :   9
#                                                            (Other):1378
#    Succession
#  Min.   :0.0000
#  1st Qu.:0.0000
#  Median :0.0000
#  Mean   :0.2495
#  3rd Qu.:0.0000
#  Max.   :1.0000

# %%
set.seed(1)

# %% [markdown]
# ### Hierarchical clustering - hclust

# %%
df <- df[,1:55]

# %%
hcmodel <- hclust(d=dist(as.matrix(df)))
hcmodel
# Out:
# Warning message in dist(as.matrix(df)):
# "NAs introduced by coercion"
# Call:
# hclust(d = dist(as.matrix(df)))
#
# Cluster method   : complete
# Distance         : euclidean
# Number of objects: 9299

# %%
options(repr.plot.width = 20, repr.plot.height = 10)
plot(hcmodel)
# Out:
# Plot with title "Cluster Dendrogram"

# %%
hcmod_clusters_3 <- cutree(hcmodel, 3)
table(hcmod_clusters_3)
table(df$Succession, clusters3=hcmod_clusters_3)

hcmod_clusters_4 <- cutree(hcmodel, 4)
table(hcmod_clusters_4)
table(df$Succession, clusters4=hcmod_clusters_4)
# Out:
# hcmod_clusters_3
#    1    2    3
# 5909 1899 1491
#    clusters3
#        1    2    3
#   0 4390 1418 1171
#   1 1519  481  320
# hcmod_clusters_4
#    1    2    3    4
# 5909 1690  209 1491
#    clusters4
#        1    2    3    4
#   0 4390 1258  160 1171
#   1 1519  432   49  320

# %%
library(mechkar)
# Out:
# Warning message:
# "package 'mechkar' was built under R version 3.6.3"

# %%
df$hclust3 <- factor(hcmod_clusters_3)
df$hclust4 <- factor(hcmod_clusters_4)

# %%
df$Succession <-factor(df$Succession)

# %%
Table1(data=df,x="Succession", y="hclust3")
Table1(data=df,x="Succession", y="hclust4")
# Out:
# Warning message in Table1(data = df, x = "Succession", y = "hclust3"):
# "The following variables have unique values and will not be included in the analysis: "
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "1"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "2"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "3"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |                                                                      |   0%
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   V1          V2 Pop           1             2           3           pval
# 1 Individuals n  9299          5909          1899        1491        NA
# 2 Succession  1  2,320 (24.9%) 1,519 (25.7%) 481 (25.3%) 320 (21.5%) 0.003
# Warning message in Table1(data = df, x = "Succession", y = "hclust4"):
# "The following variables have unique values and will not be included in the analysis: "
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "1"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "2"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "3"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "4"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |                                                                      |   0%
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   V1          V2 Pop           1             2           3          4
# 1 Individuals n  9299          5909          1690        209        1491
# 2 Succession  1  2,320 (24.9%) 1,519 (25.7%) 432 (25.6%) 49 (23.4%) 320 (21.5%)
#   pval
# 1 NA
# 2 0.007

# %%
hcmodel <- hclust(d=dist(as.matrix(df,method = "max")))
hcmodel
# Out:
# Warning message in dist(as.matrix(df, method = "max")):
# "NAs introduced by coercion"
# Call:
# hclust(d = dist(as.matrix(df, method = "max")))
#
# Cluster method   : complete
# Distance         : euclidean
# Number of objects: 9299

# %%
plot(hcmodel)
options(repr.plot.width = 30, repr.plot.height = 10)
# Out:
# Plot with title "Cluster Dendrogram"

# %% [markdown]
# ### Gaussian mixture models

# %%
library(mclust)

### Mclust: implementation of gaussian mixture model

mcl_model3 <- Mclust(df, 3)

summary(mcl_model3)

mcl_model4 <- Mclust(df, 4)

summary(mcl_model4)
# Out:
# Package 'mclust' version 5.4.5
# Type 'citation("mclust")' for citing this R package in publications.
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust VII (spherical, varying volume) model with 3 components:
#
#  log-likelihood    n  df       BIC       ICL
#       -13127208 9299 566 -26259588 -26259595
#
# Clustering table:
#    1    2    3
# 2520 1795 4984
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust VII (spherical, varying volume) model with 4 components:
#
#  log-likelihood    n  df       BIC       ICL
#       -12941443 9299 755 -25889784 -25889792
#
# Clustering table:
#    1    2    3    4
# 1538 1318 4886 1557

# %%
table(df$Succession, clusters=mcl_model3$classification)
table(df$Succession, clusters=mcl_model4$classification)
# Out:
#    clusters
#        1    2    3
#   0 1936 1434 3609
#   1  584  361 1375
#    clusters
#        1    2    3    4
#   0 1155 1038 3525 1261
#   1  383  280 1361  296

# %%
df$Mclust3 <- factor(mcl_model3$classification)
df$Mclust4 <- factor(mcl_model4$classification)

# %%
Table1(data=df,x="Succession", y="Mclust3")
Table1(data=df,x="Succession", y="Mclust4")
# Out:
# Warning message in Table1(data = df, x = "Succession", y = "Mclust3"):
# "The following variables have unique values and will not be included in the analysis: "
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "1"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "2"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "3"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |                                                                      |   0%
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   V1          V2 Pop           1           2           3             pval
# 1 Individuals n  9299          2520        1795        4984          NA
# 2 Succession  1  2,320 (24.9%) 584 (23.2%) 361 (20.1%) 1,375 (27.6%) 0
# Warning message in Table1(data = df, x = "Succession", y = "Mclust4"):
# "The following variables have unique values and will not be included in the analysis: "
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "1"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "2"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "3"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |======================================================================| 100%
# Warning message in `[<-.factor`(`*tmp*`, iseq, value = "4"):
# "invalid factor level, NA generated"
# Warning message:
# "Column `Del` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `V2` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   |                                                                      |   0%
# Warning message:
# "Column `V1` joining character vector and factor, coercing into character vector"
# Warning message:
# "Column `n` joining character vector and factor, coercing into character vector"
#   V1          V2 Pop           1           2           3
# 1 Individuals n  9299          1538        1318        4886
# 2 Succession  1  2,320 (24.9%) 383 (24.9%) 280 (21.2%) 1,361 (27.9%)
#   4           pval
# 1 1557        NA
# 2 296 (19.0%) 0

# %% [markdown]
# # Calculation of the optimal number of clusters
#
# First we will use the empiric calculation:  k ≈ √n/2

# %%
k <- sqrt(nrow(df)/2)

print(paste("The optimal number of clusters based on the empirical method is:",k))
# Out:
# [1] "The optimal number of clusters based on the empirical method is: 68.1872422084953"

# %% [markdown]
# ## External Evaluation of the clusters
#
# Pairwise measures - Confusion matrix ( TP,TN,FP,FN )
# - Jaccard index:  TP/(TP+FP+FN)
# - Rand measure:   TP+TN/(TP+FP+FN+TN)
# - Fowlkes–Mallows index:   TP/√((TP+FP)(TP+FN))

# %%
### Confission matrix for hclust
table(model=hcmod_clusters_3,observed=df$Succession)
# Out:
#      observed
# model    0    1
#     1 4390 1519
#     2 1418  481
#     3 1171  320

# %%
library('clusteval')

jaccard_hclust3 <- cluster_similarity(df$Succession, hcmod_clusters_3, similarity="jaccard", method="independence")
rand_hclust3 <- cluster_similarity(df$Succession, hcmod_clusters_3, similarity="rand", method="independence")

jaccard_hclust4 <- cluster_similarity(df$Succession, hcmod_clusters_4, similarity="jaccard", method="independence")
rand_hclust4 <- cluster_similarity(df$Succession, hcmod_clusters_4, similarity="rand", method="independence")

jaccard_Mclust3 <- cluster_similarity(df$Succession, mcl_model3$classification, similarity="jaccard", method="independence")
rand_Mclust3 <- cluster_similarity(df$Succession, mcl_model3$classification, similarity="rand", method="independence")

jaccard_Mclust4 <- cluster_similarity(df$Succession, mcl_model4$classification, similarity="jaccard", method="independence")
rand_Mclust4 <- cluster_similarity(df$Succession, mcl_model4$classification, similarity="rand", method="independence")


print(paste("Jaccard similarity index for hclust3:",jaccard_hclust3))
print(paste("Rand similarity measure for hclust3:",rand_hclust3))

print(paste("Jaccard similarity index for hclust4:",jaccard_hclust4))
print(paste("Rand similarity measure for hclust4:",rand_hclust4))

print(paste("Jaccard similarity index for Mclust3:",jaccard_Mclust3))
print(paste("Rand similarity measure for Mclust3:",rand_Mclust3))

print(paste("Jaccard similarity index for Mclust4:",jaccard_Mclust4))
print(paste("Rand similarity measure for Mclust4:",rand_Mclust4))
# Out:
# [1] "Jaccard similarity index for hclust3: 0.36366917619549"
# [1] "Rand similarity measure for hclust3: 0.488284127073385"
# [1] "Jaccard similarity index for hclust4: 0.358619430385523"
# [1] "Rand similarity measure for hclust4: 0.486163290362753"
# [1] "Jaccard similarity index for Mclust3: 0.314736352364325"
# [1] "Rand similarity measure for Mclust3: 0.46660038406191"
# [1] "Jaccard similarity index for Mclust4: 0.282042130423257"
# [1] "Rand similarity measure for Mclust4: 0.452891256333324"

# %% [markdown]
# ## Internal evaluation of clusters

# %% [markdown]
# מדדים פנימים שמודדים את איכות המודל

# %%
## Dunn
#install.packages("clValid")
library(clValid)
dist_dunn <- dist(as.matrix(df[]), method = "euclidean") 
dunn_value3 <- dunn(distance = dist_dunn, clusters =hcmod_clusters_3)  
dunn_value3
dunn_value4 <- dunn(distance = dist_dunn, clusters =hcmod_clusters_4)  
dunn_value4
# Out:
# Warning message:
# "package 'clValid' was built under R version 3.6.3"
# Loading required package: cluster
#
# Warning message in dist(as.matrix(df[]), method = "euclidean"):
# "NAs introduced by coercion"
# [1] 0.01141311
# [1] 0.008807852

# %%
write.csv(df,"C:/Users/Mayer/Documents/DataScience/She Code/Global Activism/SC_FinalFiles/ActivismClusters.csv",row.names = FALSE)

# %% [markdown]
# ## Hierarchical Clustering on Categorical Data
#
# ### Cluster Analysis for categorical data
# credits: Anastasia Reusova <br>
# https://towardsdatascience.com/hierarchical-clustering-on-categorical-data-in-r-a27e578f2995

# %%
library(dplyr)
library(cluster)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### Creating Dissimilarity Matrix
# Dissimilarity matrix is a mathematical expression of how different, or distant, the points in a data set are from each other, so you can later group the closest ones together or separate the furthest ones — which is a core idea of clustering.
# This is the step where data types differences are important as dissimilarity matrix is based on distances between individual data points. While it is quite easy to imagine distances between numerical data points (Eucledian distances), categorical data (factors in R) does not seem as obvious.

# %%
gower.dist <- daisy(df, metric = c("gower"))
class(gower.dist)
# Out:
# Warning message in daisy(df, metric = c("gower")):
# "binary variable(s) 8, 9, 63, 64, 65, 66, 67, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112 treated as interval scaled"
# [1] "dissimilarity" "dist"

# %%
gower.dist

# %% [markdown]
# ### Choosing Clustering Algorithms

# %% [markdown]
# ### hierarchical clustering
# agglomerative (bottom-up) vs divisive (top-down) way of clustering.<br>
# <img src=https://miro.medium.com/max/1032/1*qrfDH1woi77HSuzOq7ymmA.png></img>
# <center>Credits: UC Business Analytics R Programming Guide</center><br>
# <b>Agglomerative clustering</b> will start with n clusters, where n is the number of observations, assuming that each of them is its own separate cluster. Then the algorithm will try to find most similar data points and group them, so they start forming clusters.<br>
# In contrast, <b>divisive clustering</b> will go the other way around — assuming all your n data points are one big cluster and dividing most dissimilar ones into separate groups.<br>
# <i>In general, agglomerative clustering is better in discovering small clusters, and is used by most software; divisive clustering — in discovering larger clusters.</i>

# %% [markdown]
# #### DIVISIVE CLUSTERING

# %%
divisive.clust <- diana(as.matrix(gower.dist), 
                  diss = TRUE, keep.diss = TRUE)
plot(divisive.clust, main = "Divisive")
# Out:
# Error: cannot allocate vector of size 329.9 Mb
# Traceback:
#
# 1. diana(as.matrix(gower.dist), diss = TRUE, keep.diss = TRUE)
# 2. as.matrix(gower.dist)
# 3. as.matrix.dist(gower.dist)

# %% [markdown]
# #### AGGLOMERATIVE  CLUSTERING

# %%
aggl.clust.c <- hclust(gower.dist, method = "complete")
plot(aggl.clust.c,
     main = "Agglomerative, complete linkages")
# Out:
# Error: cannot allocate vector of size 329.8 Mb
# Traceback:
#
# 1. hclust(gower.dist, method = "complete")

# %% [markdown]
# ### Assessing clusters
# Deciding between different clustering algorithms and a different number of clusters

# %%
library(fpc)

# %%
cstats.table <- function(dist, tree, k) {
clust.assess <- c("cluster.number","n","within.cluster.ss","average.within","average.between",
                  "wb.ratio","dunn2","avg.silwidth")
clust.size <- c("cluster.size")
stats.names <- c()
row.clust <- c()
output.stats <- matrix(ncol = k, nrow = length(clust.assess))
cluster.sizes <- matrix(ncol = k, nrow = k)
for(i in c(1:k)){
  row.clust[i] <- paste("Cluster-", i, " size")
}
for(i in c(2:k)){
  stats.names[i] <- paste("Test", i-1)
  
  for(j in seq_along(clust.assess)){
    output.stats[j, i] <- unlist(cluster.stats(d = dist, clustering = cutree(tree, k = i))[clust.assess])[j]
    
  }
  
  for(d in 1:k) {
    cluster.sizes[d, i] <- unlist(cluster.stats(d = dist, clustering = cutree(tree, k = i))[clust.size])[d]
    dim(cluster.sizes[d, i]) <- c(length(cluster.sizes[i]), 1)
    cluster.sizes[d, i]
    
  }
}
output.stats.df <- data.frame(output.stats)
cluster.sizes <- data.frame(cluster.sizes)
cluster.sizes[is.na(cluster.sizes)] <- 0
rows.all <- c(clust.assess, row.clust)
# rownames(output.stats.df) <- clust.assess
output <- rbind(output.stats.df, cluster.sizes)[ ,-1]
colnames(output) <- stats.names[2:k]
rownames(output) <- rows.all
is.num <- sapply(output, is.numeric)
output[is.num] <- lapply(output[is.num], round, 2)
output
}

# %%
stats.df.divisive <- cstats.table(gower.dist, divisive.clust, 12)
stats.df.divisive

# %% [markdown]
# The size of clusters is disproportional. I don't  want to work with incomparable number of observations within clusters. One of the reasons, the dataset is imbalanced, and some group of observations will outweigh all the rest in the analysis — this is not good and is likely to lead to biases.

# %%
stats.df.aggl <-cstats.table(gower.dist, aggl.clust.c, 7)
stats.df.aggl

# %% [markdown]
# ##### The agglomerative complete linkages hierarchical clustering is more balanced compared on the number of observations per group

# %% [markdown]
# ### Choosing the number of clusters
# Using "Elbow" and "Silhouette" methods to identify the best number of clusters

# %%
library(ggplot2)

# %% [markdown]
# #### Elbow

# %%
# Divisive clustering
ggplot(data = data.frame(t(cstats.table(gower.dist, divisive.clust, 15))), 
  aes(x=cluster.number, y=within.cluster.ss)) + 
  geom_point()+
  geom_line()+
  ggtitle("Divisive clustering") +
  labs(x = "Num.of clusters", y = "Within clusters sum of squares (SS)") +
  theme(plot.title = element_text(hjust = 0.5))

# %%
# Agglomerative  clustering
ggplot(data = data.frame(t(cstats.table(gower.dist, aggl.clust.c, 15))), 
  aes(x=cluster.number, y=within.cluster.ss)) + 
  geom_point()+
  geom_line()+
  ggtitle("Agglomerative clustering") +
  labs(x = "Num.of clusters", y = "Within clusters sum of squares (SS)") +
  theme(plot.title = element_text(hjust = 0.5))

# %% [markdown]
# #### Agglomerative “elbow” is smoother than divisive "elbow", but both are ambiguous and cannot be used to detecte the number of clusters

# %% [markdown]
# #### Silhouette
# When it comes to silhouette assessment, the rule is to choose the number that maximizes the silhouette coefficient because we want clusters that are distinctive (far) enough to be considered separate. <br>
# The silhouette coefficient ranges between -1 and 1, with 1 indicating good consistency within clusters, -1 — not so good

# %%
# Divisive clustering
ggplot(data = data.frame(t(cstats.table(gower.dist, divisive.clust, 15))), 
  aes(x=cluster.number, y=avg.silwidth)) + 
  geom_point()+
  geom_line()+
  ggtitle("Divisive clustering") +
  labs(x = "Num.of clusters", y = "Average silhouette width") +
  theme(plot.title = element_text(hjust = 0.5))

# %%
# Agglomerative clustering
ggplot(data = data.frame(t(cstats.table(gower.dist, aggl.clust.c, 15))), 
  aes(x=cluster.number, y=avg.silwidth)) + 
  geom_point()+
  geom_line()+
  ggtitle("Agglomerative clustering") +
  labs(x = "Num.of clusters", y = "Average silhouette width") +
  theme(plot.title = element_text(hjust = 0.5))

# %%
library("ggplot2")
library("reshape2")
library("purrr")
library("dplyr")
# let's start with a dendrogram
library("dendextend")
dendro <- as.dendrogram(aggl.clust.c)
dendro.col <- dendro %>%
  set("branches_k_color", k = 12, value =   c("darkslategray", "darkslategray4", "darkslategray3", "gold3", "darkcyan", "cyan3", "blue4","darkslateblue","darkskyblue4","darkseagreen3")) %>%
  set("branches_lwd", 0.6) %>%
  set("labels_colors", 
      value = c("darkslategray")) %>% 
  set("labels_cex", 0.5)
ggd1 <- as.ggdend(dendro.col)
ggplot(ggd1, theme = theme_minimal()) +
  labs(x = "Num. observations", y = "Height", title = "Dendrogram, k = 12")

# %%
# Radial plot looks less cluttered (and cooler)
ggplot(ggd1, labels = T) + 
  scale_y_reverse(expand = c(0.2, 0)) +
  coord_polar(theta="x")

# %% [markdown]
# ### I won't use the above clusters
