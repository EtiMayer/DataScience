# %%
import numpy as np 
import pandas as pd 
import re

# %%
df = pd.read_csv('C:/Users/Mayer/Documents/DS project/Indicators.csv')

# %%
# Create list of unique indicators, indicator codes
Indicator_array =  df[['IndicatorName','IndicatorCode']].drop_duplicates().values

# %% [markdown]
# #### Change IndicatorNames
# Create a new list of IndicatorName and IndicatorCode such that special characters like "(", ")", "," are replaced just by spaces
# This new list (modified_indicators) can be used to search for specific topics as done below

# %%
modified_indicators = []
unique_indicator_codes = []
for ele in Indicator_array:
    indicator = ele[0]
    indicator_code = ele[1].strip()
    if indicator_code not in unique_indicator_codes:
        # delete , ( ) from the IndicatorNames
        new_indicator = re.sub('[,()]',"",indicator).lower()
        # replace - with "to" and make all words into lower case
        new_indicator = re.sub('-'," to ",new_indicator).lower()
        modified_indicators.append([new_indicator,indicator_code])
        unique_indicator_codes.append(indicator_code)

Indicators = pd.DataFrame(modified_indicators,columns=['IndicatorName','IndicatorCode'])
Indicators = Indicators.drop_duplicates()


print(Indicators.shape)
# Out:
# (1344, 2)

# %%
key_word_dict = {}
key_word_dict['Demography'] = ['population','birth','death','fertility','mortality','expectancy']
key_word_dict['Food'] = ['food','grain','nutrition','calories']
key_word_dict['Trade'] = ['trade','import','export','good','shipping','shipment']
key_word_dict['Health'] = ['health','desease','hospital','mortality','doctor']
key_word_dict['Economy'] = ['income','gdp','gni','deficit','budget','market','stock','bond','infrastructure']
key_word_dict['Energy'] = ['fuel','energy','power','emission','electric','electricity','renewable','co2']
key_word_dict['Education'] = ['education','literacy']
key_word_dict['Employment'] =['employed','employment','umemployed','unemployment']
key_word_dict['Rural'] = ['rural','village']
key_word_dict['Urban'] = ['urban','city']

# %%
feature = 'Energy'
energyIndicators = []
for indicator_ele in Indicators.values:
    for ele in key_word_dict[feature]:
        word_list = indicator_ele[0].split()
        if ele in word_list or ele+'s' in word_list:
            #energyIndicators.append([indicator_ele,indicator_code])
            energyIndicators.append([indicator_ele[1]])
            print(indicator_ele)
            break
# Out:
# ['co2 emissions kt' 'EN.ATM.CO2E.KT']
# ['co2 emissions metric tons per capita' 'EN.ATM.CO2E.PC']
# ['co2 emissions from gaseous fuel consumption % of total'
#  'EN.ATM.CO2E.GF.ZS']
# ['co2 emissions from liquid fuel consumption % of total'
#  'EN.ATM.CO2E.LF.ZS']
# ['co2 emissions from liquid fuel consumption kt' 'EN.ATM.CO2E.LF.KT']
# ['co2 emissions from solid fuel consumption % of total'
#  'EN.ATM.CO2E.SF.ZS']
# ['alternative and nuclear energy % of total energy use'
#  'EG.USE.COMM.CL.ZS']
# ['co2 emissions from electricity and heat production total % of total fuel combustion'
#  'EN.CO2.ETOT.ZS']
# ['co2 emissions from manufacturing industries and construction % of total fuel combustion'
#  'EN.CO2.MANF.ZS']
# ['co2 emissions from other sectors excluding residential buildings and commercial and public services % of total fuel combustion'
#  'EN.CO2.OTHX.ZS']
# ['co2 emissions from residential buildings and commercial and public services % of total fuel combustion'
#  'EN.CO2.BLDG.ZS']
# ['co2 emissions from solid fuel consumption kt' 'EN.ATM.CO2E.SF.KT']
# ['co2 emissions from transport % of total fuel combustion'
#  'EN.CO2.TRAN.ZS']
# ['co2 intensity kg per kg of oil equivalent energy use'
#  'EN.ATM.CO2E.EG.ZS']
# ['combustible renewables and waste % of total energy' 'EG.USE.CRNW.ZS']
# ['electric power transmission and distribution losses % of output'
#  'EG.ELC.LOSS.ZS']
# ['electricity production from renewable sources excluding hydroelectric kwh'
#  'EG.ELC.RNWX.KH']
# ['energy imports net % of energy use' 'EG.IMP.CONS.ZS']
# ['fossil fuel energy consumption % of total' 'EG.USE.COMM.FO.ZS']
# ['co2 emissions kg per 2005 us$ of gdp' 'EN.ATM.CO2E.KD.GD']
# ['electric power consumption kwh per capita' 'EG.USE.ELEC.KH.PC']
# ['electricity production from coal sources % of total' 'EG.ELC.COAL.ZS']
# ['electricity production from hydroelectric sources % of total'
#  'EG.ELC.HYRO.ZS']
# ['electricity production from natural gas sources % of total'
#  'EG.ELC.NGAS.ZS']
# ['electricity production from nuclear sources % of total' 'EG.ELC.NUCL.ZS']
# ['electricity production from oil sources % of total' 'EG.ELC.PETR.ZS']
# ['electricity production from oil gas and coal sources % of total'
#  'EG.ELC.FOSL.ZS']
# ['electricity production from renewable sources excluding hydroelectric % of total'
#  'EG.ELC.RNWX.ZS']
# ['energy use kg of oil equivalent per capita' 'EG.USE.PCAP.KG.OE']
# ['co2 emissions from gaseous fuel consumption kt' 'EN.ATM.CO2E.GF.KT']
# ['renewable internal freshwater resources per capita cubic meters'
#  'ER.H2O.INTR.PC']
# ['renewable internal freshwater resources total billion cubic meters'
#  'ER.H2O.INTR.K3']
# ['fuel exports % of merchandise exports' 'TX.VAL.FUEL.ZS.UN']
# ['fuel imports % of merchandise imports' 'TM.VAL.FUEL.ZS.UN']
# ['adjusted savings: energy depletion % of gni' 'NY.ADJ.DNGY.GN.ZS']
# ['adjusted net savings excluding particulate emission damage % of gni'
#  'NY.ADJ.SVNX.GN.ZS']
# ['adjusted savings: energy depletion current us$' 'NY.ADJ.DNGY.CD']
# ['adjusted net savings excluding particulate emission damage current us$'
#  'NY.ADJ.SVNX.CD']
# ['access to electricity % of population' 'EG.ELC.ACCS.ZS']
# ['access to electricity rural % of rural population' 'EG.ELC.ACCS.RU.ZS']
# ['access to electricity urban % of urban population' 'EG.ELC.ACCS.UR.ZS']
# ['access to non to solid fuel % of population' 'EG.NSF.ACCS.ZS']
# ['adjusted net savings including particulate emission damage % of gni'
#  'NY.ADJ.SVNG.GN.ZS']
# ['adjusted savings: particulate emission damage % of gni'
#  'NY.ADJ.DPEM.GN.ZS']
# ['agricultural methane emissions % of total' 'EN.ATM.METH.AG.ZS']
# ['agricultural nitrous oxide emissions % of total' 'EN.ATM.NOXE.AG.ZS']
# ['co2 emissions kg per 2011 ppp $ of gdp' 'EN.ATM.CO2E.PP.GD.KD']
# ['co2 emissions kg per ppp $ of gdp' 'EN.ATM.CO2E.PP.GD']
# ['energy intensity level of primary energy mj/$2011 ppp gdp'
#  'EG.EGY.PRIM.PP.KD']
# ['energy related methane emissions % of total' 'EN.ATM.METH.EG.ZS']
# ['energy use kg of oil equivalent per $1000 gdp constant 2011 ppp'
#  'EG.USE.COMM.GD.PP.KD']
# ['gdp per unit of energy use constant 2011 ppp $ per kg of oil equivalent'
#  'EG.GDP.PUSE.KO.PP.KD']
# ['gdp per unit of energy use ppp $ per kg of oil equivalent'
#  'EG.GDP.PUSE.KO.PP']
# ['methane emissions kt of co2 equivalent' 'EN.ATM.METH.KT.CE']
# ['methane emissions in energy sector thousand metric tons of co2 equivalent'
#  'EN.ATM.METH.EG.KT.CE']
# ['nitrous oxide emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.NOXE.KT.CE']
# ['nitrous oxide emissions in energy sector thousand metric tons of co2 equivalent'
#  'EN.ATM.NOXE.EG.KT.CE']
# ['nitrous oxide emissions in industrial and energy processes % of total nitrous oxide emissions'
#  'EN.ATM.NOXE.EI.ZS']
# ['other greenhouse gas emissions hfc pfc and sf6 thousand metric tons of co2 equivalent'
#  'EN.ATM.GHGO.KT.CE']
# ['renewable electricity output % of total electricity output'
#  'EG.ELC.RNEW.ZS']
# ['renewable energy consumption % of total final energy consumption'
#  'EG.FEC.RNEW.ZS']
# ['sf6 gas emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.SF6G.KT.CE']
# ['hfc gas emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.HFCG.KT.CE']
# ['pfc gas emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.PFCG.KT.CE']
# ['adjusted net savings including particulate emission damage current us$'
#  'NY.ADJ.SVNG.CD']
# ['adjusted savings: particulate emission damage current us$'
#  'NY.ADJ.DPEM.CD']
# ['agricultural methane emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.METH.AG.KT.CE']
# ['agricultural nitrous oxide emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.NOXE.AG.KT.CE']
# ['industrial nitrous oxide emissions thousand metric tons of co2 equivalent'
#  'EN.ATM.NOXE.IN.KT.CE']
# ['ghg net emissions/removals by lucf mt of co2 equivalent'
#  'EN.CLC.GHGR.MT.CE']
# ['investment in energy with private participation current us$'
#  'IE.PPI.ENGY.CD']
# ['pump price for diesel fuel us$ per liter' 'EP.PMP.DESL.CD']
# ['power outages in firms in a typical month number' 'IC.ELC.OUTG']
# ['time required to get electricity days' 'IC.ELC.TIME']
# ['access to non to solid fuel rural % of rural population'
#  'EG.NSF.ACCS.RU.ZS']
# ['access to non to solid fuel urban % of urban population'
#  'EG.NSF.ACCS.UR.ZS']

# %%
energyIndicators
# Out:
# [['EN.ATM.CO2E.KT'],
#  ['EN.ATM.CO2E.PC'],
#  ['EN.ATM.CO2E.GF.ZS'],
#  ['EN.ATM.CO2E.LF.ZS'],
#  ['EN.ATM.CO2E.LF.KT'],
#  ['EN.ATM.CO2E.SF.ZS'],
#  ['EG.USE.COMM.CL.ZS'],
#  ['EN.CO2.ETOT.ZS'],
#  ['EN.CO2.MANF.ZS'],
#  ['EN.CO2.OTHX.ZS'],
#  ['EN.CO2.BLDG.ZS'],
#  ['EN.ATM.CO2E.SF.KT'],
#  ['EN.CO2.TRAN.ZS'],
#  ['EN.ATM.CO2E.EG.ZS'],
#  ['EG.USE.CRNW.ZS'],
#  ['EG.ELC.LOSS.ZS'],
#  ['EG.ELC.RNWX.KH'],
#  ['EG.IMP.CONS.ZS'],
#  ['EG.USE.COMM.FO.ZS'],
#  ['EN.ATM.CO2E.KD.GD'],
#  ['EG.USE.ELEC.KH.PC'],
#  ['EG.ELC.COAL.ZS'],
#  ['EG.ELC.HYRO.ZS'],
#  ['EG.ELC.NGAS.ZS'],
#  ['EG.ELC.NUCL.ZS'],
#  ['EG.ELC.PETR.ZS'],
#  ['EG.ELC.FOSL.ZS'],
#  ['EG.ELC.RNWX.ZS'],
#  ['EG.USE.PCAP.KG.OE'],
#  ['EN.ATM.CO2E.GF.KT'],
#  ['ER.H2O.INTR.PC'],
#  ['ER.H2O.INTR.K3'],
#  ['TX.VAL.FUEL.ZS.UN'],
#  ['TM.VAL.FUEL.ZS.UN'],
#  ['NY.ADJ.DNGY.GN.ZS'],
#  ['NY.ADJ.SVNX.GN.ZS'],
#  ['NY.ADJ.DNGY.CD'],
#  ['NY.ADJ.SVNX.CD'],
#  ['EG.ELC.ACCS.ZS'],
#  ['EG.ELC.ACCS.RU.ZS'],
#  ['EG.ELC.ACCS.UR.ZS'],
#  ['EG.NSF.ACCS.ZS'],
#  ['NY.ADJ.SVNG.GN.ZS'],
#  ['NY.ADJ.DPEM.GN.ZS'],
#  ['EN.ATM.METH.AG.ZS'],
#  ['EN.ATM.NOXE.AG.ZS'],
#  ['EN.ATM.CO2E.PP.GD.KD'],
#  ['EN.ATM.CO2E.PP.GD'],
#  ['EG.EGY.PRIM.PP.KD'],
#  ['EN.ATM.METH.EG.ZS'],
#  ['EG.USE.COMM.GD.PP.KD'],
#  ['EG.GDP.PUSE.KO.PP.KD'],
#  ['EG.GDP.PUSE.KO.PP'],
#  ['EN.ATM.METH.KT.CE'],
#  ['EN.ATM.METH.EG.KT.CE'],
#  ['EN.ATM.NOXE.KT.CE'],
#  ['EN.ATM.NOXE.EG.KT.CE'],
#  ['EN.ATM.NOXE.EI.ZS'],
#  ['EN.ATM.GHGO.KT.CE'],
#  ['EG.ELC.RNEW.ZS'],
#  ['EG.FEC.RNEW.ZS'],
#  ['EN.ATM.SF6G.KT.CE'],
#  ['EN.ATM.HFCG.KT.CE'],
#  ['EN.ATM.PFCG.KT.CE'],
#  ['NY.ADJ.SVNG.CD'],
#  ['NY.ADJ.DPEM.CD'],
#  ['EN.ATM.METH.AG.KT.CE'],
#  ['EN.ATM.NOXE.AG.KT.CE'],
#  ['EN.ATM.NOXE.IN.KT.CE'],
#  ['EN.CLC.GHGR.MT.CE'],
#  ['IE.PPI.ENGY.CD'],
#  ['EP.PMP.DESL.CD'],
#  ['IC.ELC.OUTG'],
#  ['IC.ELC.TIME'],
#  ['EG.NSF.ACCS.RU.ZS'],
#  ['EG.NSF.ACCS.UR.ZS']]

# %%
type(energyIndicators)
# Out:
# list

# %%
import itertools
energyIndicators = list(itertools.chain(energyIndicators))

# %%
energyIndicators = pd.DataFrame(energyIndicators)
energyIndicators
# Out:
#                        0
# 0         EN.ATM.CO2E.KT
# 1         EN.ATM.CO2E.PC
# 2      EN.ATM.CO2E.GF.ZS
# 3      EN.ATM.CO2E.LF.ZS
# 4      EN.ATM.CO2E.LF.KT
# 5      EN.ATM.CO2E.SF.ZS
# 6      EG.USE.COMM.CL.ZS
# 7         EN.CO2.ETOT.ZS
# 8         EN.CO2.MANF.ZS
# 9         EN.CO2.OTHX.ZS
# 10        EN.CO2.BLDG.ZS
# 11     EN.ATM.CO2E.SF.KT
# 12        EN.CO2.TRAN.ZS
# 13     EN.ATM.CO2E.EG.ZS
# 14        EG.USE.CRNW.ZS
# 15        EG.ELC.LOSS.ZS
# 16        EG.ELC.RNWX.KH
# 17        EG.IMP.CONS.ZS
# 18     EG.USE.COMM.FO.ZS
# 19     EN.ATM.CO2E.KD.GD
# 20     EG.USE.ELEC.KH.PC
# 21        EG.ELC.COAL.ZS
# 22        EG.ELC.HYRO.ZS
# 23        EG.ELC.NGAS.ZS
# 24        EG.ELC.NUCL.ZS
# 25        EG.ELC.PETR.ZS
# 26        EG.ELC.FOSL.ZS
# 27        EG.ELC.RNWX.ZS
# 28     EG.USE.PCAP.KG.OE
# 29     EN.ATM.CO2E.GF.KT
# ..                   ...
# 46  EN.ATM.CO2E.PP.GD.KD
# 47     EN.ATM.CO2E.PP.GD
# 48     EG.EGY.PRIM.PP.KD
# 49     EN.ATM.METH.EG.ZS
# 50  EG.USE.COMM.GD.PP.KD
# 51  EG.GDP.PUSE.KO.PP.KD
# 52     EG.GDP.PUSE.KO.PP
# 53     EN.ATM.METH.KT.CE
# 54  EN.ATM.METH.EG.KT.CE
# 55     EN.ATM.NOXE.KT.CE
# 56  EN.ATM.NOXE.EG.KT.CE
# 57     EN.ATM.NOXE.EI.ZS
# 58     EN.ATM.GHGO.KT.CE
# 59        EG.ELC.RNEW.ZS
# 60        EG.FEC.RNEW.ZS
# 61     EN.ATM.SF6G.KT.CE
# 62     EN.ATM.HFCG.KT.CE
# 63     EN.ATM.PFCG.KT.CE
# 64        NY.ADJ.SVNG.CD
# 65        NY.ADJ.DPEM.CD
# 66  EN.ATM.METH.AG.KT.CE
# 67  EN.ATM.NOXE.AG.KT.CE
# 68  EN.ATM.NOXE.IN.KT.CE
# 69     EN.CLC.GHGR.MT.CE
# 70        IE.PPI.ENGY.CD
# 71        EP.PMP.DESL.CD
# 72           IC.ELC.OUTG
# 73           IC.ELC.TIME
# 74     EG.NSF.ACCS.RU.ZS
# 75     EG.NSF.ACCS.UR.ZS
#
# [76 rows x 1 columns]

# %%
energyIndicators = energyIndicators.rename(columns={0: 'IndicatorCode'})
energyIndicators
# Out:
#            IndicatorCode
# 0         EN.ATM.CO2E.KT
# 1         EN.ATM.CO2E.PC
# 2      EN.ATM.CO2E.GF.ZS
# 3      EN.ATM.CO2E.LF.ZS
# 4      EN.ATM.CO2E.LF.KT
# 5      EN.ATM.CO2E.SF.ZS
# 6      EG.USE.COMM.CL.ZS
# 7         EN.CO2.ETOT.ZS
# 8         EN.CO2.MANF.ZS
# 9         EN.CO2.OTHX.ZS
# 10        EN.CO2.BLDG.ZS
# 11     EN.ATM.CO2E.SF.KT
# 12        EN.CO2.TRAN.ZS
# 13     EN.ATM.CO2E.EG.ZS
# 14        EG.USE.CRNW.ZS
# 15        EG.ELC.LOSS.ZS
# 16        EG.ELC.RNWX.KH
# 17        EG.IMP.CONS.ZS
# 18     EG.USE.COMM.FO.ZS
# 19     EN.ATM.CO2E.KD.GD
# 20     EG.USE.ELEC.KH.PC
# 21        EG.ELC.COAL.ZS
# 22        EG.ELC.HYRO.ZS
# 23        EG.ELC.NGAS.ZS
# 24        EG.ELC.NUCL.ZS
# 25        EG.ELC.PETR.ZS
# 26        EG.ELC.FOSL.ZS
# 27        EG.ELC.RNWX.ZS
# 28     EG.USE.PCAP.KG.OE
# 29     EN.ATM.CO2E.GF.KT
# ..                   ...
# 46  EN.ATM.CO2E.PP.GD.KD
# 47     EN.ATM.CO2E.PP.GD
# 48     EG.EGY.PRIM.PP.KD
# 49     EN.ATM.METH.EG.ZS
# 50  EG.USE.COMM.GD.PP.KD
# 51  EG.GDP.PUSE.KO.PP.KD
# 52     EG.GDP.PUSE.KO.PP
# 53     EN.ATM.METH.KT.CE
# 54  EN.ATM.METH.EG.KT.CE
# 55     EN.ATM.NOXE.KT.CE
# 56  EN.ATM.NOXE.EG.KT.CE
# 57     EN.ATM.NOXE.EI.ZS
# 58     EN.ATM.GHGO.KT.CE
# 59        EG.ELC.RNEW.ZS
# 60        EG.FEC.RNEW.ZS
# 61     EN.ATM.SF6G.KT.CE
# 62     EN.ATM.HFCG.KT.CE
# 63     EN.ATM.PFCG.KT.CE
# 64        NY.ADJ.SVNG.CD
# 65        NY.ADJ.DPEM.CD
# 66  EN.ATM.METH.AG.KT.CE
# 67  EN.ATM.NOXE.AG.KT.CE
# 68  EN.ATM.NOXE.IN.KT.CE
# 69     EN.CLC.GHGR.MT.CE
# 70        IE.PPI.ENGY.CD
# 71        EP.PMP.DESL.CD
# 72           IC.ELC.OUTG
# 73           IC.ELC.TIME
# 74     EG.NSF.ACCS.RU.ZS
# 75     EG.NSF.ACCS.UR.ZS
#
# [76 rows x 1 columns]

# %%
energyIndicators1 = pd.merge(energyIndicators,df[['IndicatorCode','IndicatorName']],on='IndicatorCode',how='inner')

# %%
energyIndicators1
# Out:
#             IndicatorCode                                      IndicatorName
# 0          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 1          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 2          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 3          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 4          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 5          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 6          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 7          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 8          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 9          EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 10         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 11         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 12         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 13         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 14         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 15         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 16         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 17         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 18         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 19         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 20         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 21         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 22         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 23         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 24         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 25         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 26         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 27         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 28         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 29         EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# ...                   ...                                                ...
# 345304  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345305  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345306  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345307  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345308  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345309  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345310  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345311  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345312  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345313  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345314  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345315  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345316  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345317  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345318  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345319  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345320  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345321  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345322  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345323  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345324  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345325  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345326  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345327  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345328  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345329  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345330  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345331  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345332  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
# 345333  EG.NSF.ACCS.UR.ZS  Access to non-solid fuel, urban (% of urban po...
#
# [345334 rows x 2 columns]

# %%
#creating full table (FT) of Renewable Energy indicators including values
energyIndicatorsFT=pd.merge(energyIndicators,df,how='inner',sort=False)
energyIndicatorsFT = energyIndicatorsFT.sort_values(['CountryCode','Year'],ascending=[1,1])

# %%
energyIndicatorsFT
# Out:
#                IndicatorCode CountryName CountryCode  \
# 271312        NY.ADJ.DNGY.CD       Aruba         ABW
# 271526        NY.ADJ.DNGY.CD       Aruba         ABW
# 271740        NY.ADJ.DNGY.CD       Aruba         ABW
# 271954        NY.ADJ.DNGY.CD       Aruba         ABW
# 272168        NY.ADJ.DNGY.CD       Aruba         ABW
# 272382        NY.ADJ.DNGY.CD       Aruba         ABW
# 272596        NY.ADJ.DNGY.CD       Aruba         ABW
# 272810        NY.ADJ.DNGY.CD       Aruba         ABW
# 273024        NY.ADJ.DNGY.CD       Aruba         ABW
# 273238        NY.ADJ.DNGY.CD       Aruba         ABW
# 273447        NY.ADJ.DNGY.CD       Aruba         ABW
# 273661        NY.ADJ.DNGY.CD       Aruba         ABW
# 273875        NY.ADJ.DNGY.CD       Aruba         ABW
# 274089        NY.ADJ.DNGY.CD       Aruba         ABW
# 274303        NY.ADJ.DNGY.CD       Aruba         ABW
# 274517        NY.ADJ.DNGY.CD       Aruba         ABW
# 4933          EN.ATM.CO2E.KT       Aruba         ABW
# 15535         EN.ATM.CO2E.PC       Aruba         ABW
# 26247      EN.ATM.CO2E.GF.ZS       Aruba         ABW
# 36990      EN.ATM.CO2E.LF.ZS       Aruba         ABW
# 47595      EN.ATM.CO2E.LF.KT       Aruba         ABW
# 58317      EN.ATM.CO2E.SF.ZS       Aruba         ABW
# 103701     EN.ATM.CO2E.SF.KT       Aruba         ABW
# 232067     EN.ATM.CO2E.GF.KT       Aruba         ABW
# 274731        NY.ADJ.DNGY.CD       Aruba         ABW
# 5126          EN.ATM.CO2E.KT       Aruba         ABW
# 15728         EN.ATM.CO2E.PC       Aruba         ABW
# 26444      EN.ATM.CO2E.GF.ZS       Aruba         ABW
# 37187      EN.ATM.CO2E.LF.ZS       Aruba         ABW
# 47787      EN.ATM.CO2E.LF.KT       Aruba         ABW
# ...                      ...         ...         ...
# 248969     TX.VAL.FUEL.ZS.UN    Zimbabwe         ZWE
# 256485     TM.VAL.FUEL.ZS.UN    Zimbabwe         ZWE
# 265186     NY.ADJ.DNGY.GN.ZS    Zimbabwe         ZWE
# 280462        NY.ADJ.DNGY.CD    Zimbabwe         ZWE
# 286391        EG.ELC.ACCS.ZS    Zimbabwe         ZWE
# 287371     EG.ELC.ACCS.RU.ZS    Zimbabwe         ZWE
# 288351     EG.ELC.ACCS.UR.ZS    Zimbabwe         ZWE
# 289247        EG.NSF.ACCS.ZS    Zimbabwe         ZWE
# 306616     EG.EGY.PRIM.PP.KD    Zimbabwe         ZWE
# 311126  EG.USE.COMM.GD.PP.KD    Zimbabwe         ZWE
# 314846  EG.GDP.PUSE.KO.PP.KD    Zimbabwe         ZWE
# 318565     EG.GDP.PUSE.KO.PP    Zimbabwe         ZWE
# 328609        EG.ELC.RNEW.ZS    Zimbabwe         ZWE
# 333476        EG.FEC.RNEW.ZS    Zimbabwe         ZWE
# 342508        EP.PMP.DESL.CD    Zimbabwe         ZWE
# 343774           IC.ELC.TIME    Zimbabwe         ZWE
# 344885     EG.NSF.ACCS.RU.ZS    Zimbabwe         ZWE
# 345333     EG.NSF.ACCS.UR.ZS    Zimbabwe         ZWE
# 239852        ER.H2O.INTR.PC    Zimbabwe         ZWE
# 242175        ER.H2O.INTR.K3    Zimbabwe         ZWE
# 249131     TX.VAL.FUEL.ZS.UN    Zimbabwe         ZWE
# 256652     TM.VAL.FUEL.ZS.UN    Zimbabwe         ZWE
# 265406     NY.ADJ.DNGY.GN.ZS    Zimbabwe         ZWE
# 280675        NY.ADJ.DNGY.CD    Zimbabwe         ZWE
# 343995           IC.ELC.TIME    Zimbabwe         ZWE
# 249254     TX.VAL.FUEL.ZS.UN    Zimbabwe         ZWE
# 256779     TM.VAL.FUEL.ZS.UN    Zimbabwe         ZWE
# 342703        EP.PMP.DESL.CD    Zimbabwe         ZWE
# 344216           IC.ELC.TIME    Zimbabwe         ZWE
# 344437           IC.ELC.TIME    Zimbabwe         ZWE
#
#                                             IndicatorName  Year         Value
# 271312   Adjusted savings: energy depletion (current US$)  1970  0.000000e+00
# 271526   Adjusted savings: energy depletion (current US$)  1971  0.000000e+00
# 271740   Adjusted savings: energy depletion (current US$)  1972  0.000000e+00
# 271954   Adjusted savings: energy depletion (current US$)  1973  0.000000e+00
# 272168   Adjusted savings: energy depletion (current US$)  1974  0.000000e+00
# 272382   Adjusted savings: energy depletion (current US$)  1975  0.000000e+00
# 272596   Adjusted savings: energy depletion (current US$)  1976  0.000000e+00
# 272810   Adjusted savings: energy depletion (current US$)  1977  0.000000e+00
# 273024   Adjusted savings: energy depletion (current US$)  1978  0.000000e+00
# 273238   Adjusted savings: energy depletion (current US$)  1979  0.000000e+00
# 273447   Adjusted savings: energy depletion (current US$)  1980  0.000000e+00
# 273661   Adjusted savings: energy depletion (current US$)  1981  0.000000e+00
# 273875   Adjusted savings: energy depletion (current US$)  1982  0.000000e+00
# 274089   Adjusted savings: energy depletion (current US$)  1983  0.000000e+00
# 274303   Adjusted savings: energy depletion (current US$)  1984  0.000000e+00
# 274517   Adjusted savings: energy depletion (current US$)  1985  0.000000e+00
# 4933                                   CO2 emissions (kt)  1986  1.796830e+02
# 15535              CO2 emissions (metric tons per capita)  1986  2.868319e+00
# 26247   CO2 emissions from gaseous fuel consumption (%...  1986  0.000000e+00
# 36990   CO2 emissions from liquid fuel consumption (% ...  1986  1.000000e+02
# 47595     CO2 emissions from liquid fuel consumption (kt)  1986  1.796830e+02
# 58317   CO2 emissions from solid fuel consumption (% o...  1986  0.000000e+00
# 103701     CO2 emissions from solid fuel consumption (kt)  1986  0.000000e+00
# 232067   CO2 emissions from gaseous fuel consumption (kt)  1986  0.000000e+00
# 274731   Adjusted savings: energy depletion (current US$)  1986  0.000000e+00
# 5126                                   CO2 emissions (kt)  1987  4.473740e+02
# 15728              CO2 emissions (metric tons per capita)  1987  7.234964e+00
# 26444   CO2 emissions from gaseous fuel consumption (%...  1987  0.000000e+00
# 37187   CO2 emissions from liquid fuel consumption (% ...  1987  1.000000e+02
# 47787     CO2 emissions from liquid fuel consumption (kt)  1987  4.473740e+02
# ...                                                   ...   ...           ...
# 248969            Fuel exports (% of merchandise exports)  2012  1.160601e+00
# 256485            Fuel imports (% of merchandise imports)  2012  2.055637e+01
# 265186      Adjusted savings: energy depletion (% of GNI)  2012  6.684813e-01
# 280462   Adjusted savings: energy depletion (current US$)  2012  7.696493e+07
# 286391            Access to electricity (% of population)  2012  4.046256e+01
# 287371  Access to electricity, rural (% of rural popul...  2012  1.605460e+01
# 288351  Access to electricity, urban (% of urban popul...  2012  7.846117e+01
# 289247         Access to non-solid fuel (% of population)  2012  2.964798e+01
# 306616  Energy intensity level of primary energy (MJ/$...  2012  1.753233e+01
# 311126  Energy use (kg of oil equivalent) per $1,000 G...  2012  3.988770e+02
# 314846  GDP per unit of energy use (constant 2011 PPP ...  2012  2.507038e+00
# 318565  GDP per unit of energy use (PPP $ per kg of oi...  2012  2.552045e+00
# 328609  Renewable electricity output (% of total elect...  2012  5.996919e+01
# 333476  Renewable energy consumption (% of total final...  2012  7.560253e+01
# 342508         Pump price for diesel fuel (US$ per liter)  2012  1.400000e+00
# 343774            Time required to get electricity (days)  2012  1.060000e+02
# 344885  Access to non-solid fuel, rural (% of rural po...  2012  5.583417e+00
# 345333  Access to non-solid fuel, urban (% of urban po...  2012  6.711198e+01
# 239852  Renewable internal freshwater resources per ca...  2013  8.229242e+02
# 242175  Renewable internal freshwater resources, total...  2013  1.226000e+01
# 249131            Fuel exports (% of merchandise exports)  2013  1.137389e+00
# 256652            Fuel imports (% of merchandise imports)  2013  2.099620e+01
# 265406      Adjusted savings: energy depletion (% of GNI)  2013  4.904864e-01
# 280675   Adjusted savings: energy depletion (current US$)  2013  6.117346e+07
# 343995            Time required to get electricity (days)  2013  1.060000e+02
# 249254            Fuel exports (% of merchandise exports)  2014  5.556535e-01
# 256779            Fuel imports (% of merchandise imports)  2014  2.455169e+01
# 342703         Pump price for diesel fuel (US$ per liter)  2014  1.480000e+00
# 344216            Time required to get electricity (days)  2014  1.060000e+02
# 344437            Time required to get electricity (days)  2015  1.060000e+02
#
# [345334 rows x 6 columns]

# %%
energyIndicatorsFT.to_csv(r'C:\Users\Mayer\Documents\DS project\EnergyIndicatorsFT.csv',index=False)

# %%
energyIndicators1.to_csv(r'C:\Users\Mayer\Documents\DS project\EnergyIndicators1.csv',index=False)
