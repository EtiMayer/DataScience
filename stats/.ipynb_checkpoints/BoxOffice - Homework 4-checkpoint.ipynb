# %% [markdown]
# # עבודת סיכום מס' 4

# %%
library(DBI)
library(odbc)
library(RSQLite)
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
sort(unique(odbcListDrivers()[[1]]))
# Out:
# [1] "ODBC Driver 11 for SQL Server" "SQL Server"
# [3] "SQL Server Native Client 11.0"

# %%
con <- dbConnect(odbc(), 
                 Driver = "SQL Server", 
                 Server = "DESKTOP-AAGNMGA\\SQLEXPRESS", 
                 Database = "BoxOffice", 
                 Trusted_Connection = "True")

# %%
 movies_ff <- dbReadTable(con,"movies_ff_v")

# %%
# save(movies_ff,file="C:/Users/Mayer/Documents/DataScience/data/BoxOffice_ff.RData")

# %%
BoxOffice_ff <- load("C:/Users/Mayer/Documents/DataScience/data/BoxOffice_ff.RData")

# %% [markdown]
# ### Exploratory data analysis - חלק 2 - בדיקת הנתונים

# %% [markdown]
# ###  2.1 Descriptive Statistics for BoxOffice

# %%
summary(movies_ff)
# Out:
#     movie_id    original_language  release_date       runtime_cat
#  Min.   :   1   Length:7375        Length:7375        Length:7375
#  1st Qu.:1848   Class :character   Class :character   Class :character
#  Median :3696   Mode  :character   Mode  :character   Mode  :character
#  Mean   :3698
#  3rd Qu.:5550
#  Max.   :7398
#
#     runtime        budget            popularity     revenue
#  Min.   :  0   Min.   :        0   Min.   :  0   Min.   :         1
#  1st Qu.: 94   1st Qu.:        0   1st Qu.:  4   1st Qu.:   2405420
#  Median :104   Median :  8000000   Median :  7   Median :  16928137
#  Mean   :108   Mean   : 22666657   Mean   :  9   Mean   :  66879312
#  3rd Qu.:118   3rd Qu.: 29000000   3rd Qu.: 11   3rd Qu.:  69055695
#  Max.   :338   Max.   :380000000   Max.   :547   Max.   :1519557910
#  NA's   :5                                       NA's   :4382
#    sw_lang_en   sw_web_presence sw_has_poster   sw_tagline   keyword_cnt
#  Min.   :0.00   Min.   :0.00    Min.   :0     Min.   :0.0   Min.   :  0
#  1st Qu.:1.00   1st Qu.:0.00    1st Qu.:1     1st Qu.:1.0   1st Qu.:  3
#  Median :1.00   Median :0.00    Median :1     Median :1.0   Median :  6
#  Mean   :0.86   Mean   :0.32    Mean   :1     Mean   :0.8   Mean   :  7
#  3rd Qu.:1.00   3rd Qu.:1.00    3rd Qu.:1     3rd Qu.:1.0   3rd Qu.: 10
#  Max.   :1.00   Max.   :1.00    Max.   :1     Max.   :1.0   Max.   :149
#
#   release_year  release_month  high_release_month  release_day
#  Min.   :1918   Min.   : 1.0   Min.   :0.0        Min.   : 1.0
#  1st Qu.:1992   1st Qu.: 4.0   1st Qu.:0.0        1st Qu.: 8.0
#  Median :2004   Median : 7.0   Median :0.0        Median :15.0
#  Mean   :2000   Mean   : 6.8   Mean   :0.4        Mean   :15.2
#  3rd Qu.:2011   3rd Qu.:10.0   3rd Qu.:1.0        3rd Qu.:22.0
#  Max.   :2017   Max.   :12.0   Max.   :1.0        Max.   :31.0
#  NA's   :1      NA's   :1                         NA's   :1
#   seasonality        sw_collection  producers_cnt countries_cnt     lang_US
#  Min.   :-50746591   Min.   :0.00   Min.   : 1    Min.   : 0.0   Min.   :0.00
#  1st Qu.:-33273015   1st Qu.:0.00   1st Qu.: 1    1st Qu.: 1.0   1st Qu.:1.00
#  Median :-15309317   Median :0.00   Median : 2    Median : 1.0   Median :1.00
#  Mean   : -1337484   Mean   :0.03   Mean   : 3    Mean   : 1.3   Mean   :0.87
#  3rd Qu.: 32322910   3rd Qu.:0.00   3rd Qu.: 4    3rd Qu.: 1.0   3rd Qu.:1.00
#  Max.   : 74205073   Max.   :2.00   Max.   :26    Max.   :12.0   Max.   :1.00
#  NA's   :1                          NA's   :395
#     lang_FR       lang_RU        lang_ES        lang_JA      keywords_cnt
#  Min.   :0.0   Min.   :0.00   Min.   :0.00   Min.   :0.00   Min.   :  0
#  1st Qu.:0.0   1st Qu.:0.00   1st Qu.:0.00   1st Qu.:0.00   1st Qu.:  3
#  Median :0.0   Median :0.00   Median :0.00   Median :0.00   Median :  6
#  Mean   :0.1   Mean   :0.05   Mean   :0.08   Mean   :0.03   Mean   :  7
#  3rd Qu.:0.0   3rd Qu.:0.00   3rd Qu.:0.00   3rd Qu.:0.00   3rd Qu.: 10
#  Max.   :1.0   Max.   :1.00   Max.   :1.00   Max.   :1.00   Max.   :149
#
#  actor0_movies_cnt actor0_movies_5y_cnt actor1_movies_cnt actor1_movies_5y_cnt
#  Min.   : 0        Min.   : 0.0         Min.   : 0        Min.   : 0.0
#  1st Qu.: 0        1st Qu.: 0.0         1st Qu.: 0        1st Qu.: 0.0
#  Median : 4        Median : 2.0         Median : 2        Median : 1.0
#  Mean   : 7        Mean   : 2.8         Mean   : 5        Mean   : 2.3
#  3rd Qu.:11        3rd Qu.: 5.0         3rd Qu.: 8        3rd Qu.: 4.0
#  Max.   :65        Max.   :16.0         Max.   :67        Max.   :17.0
#
#  actor2_movies_cnt actor2_movies_5y_cnt sw_female_actor0 sw_female_actor1
#  Min.   : 0        Min.   : 0.0         Min.   :0        Min.   :0
#  1st Qu.: 0        1st Qu.: 0.0         1st Qu.:0        1st Qu.:0
#  Median : 2        Median : 1.0         Median :0        Median :0
#  Mean   : 5        Mean   : 1.9         Mean   :0        Mean   :0
#  3rd Qu.: 7        3rd Qu.: 3.0         3rd Qu.:0        3rd Qu.:1
#  Max.   :68        Max.   :15.0         Max.   :1        Max.   :1
#                                         NA's   :934      NA's   :782
#  sw_female_actor2 sw_male_actor0 sw_male_actor1 sw_male_actor2
#  Min.   :0        Min.   :0      Min.   :0      Min.   :0
#  1st Qu.:0        1st Qu.:0      1st Qu.:0      1st Qu.:0
#  Median :0        Median :1      Median :1      Median :1
#  Mean   :0        Mean   :1      Mean   :1      Mean   :1
#  3rd Qu.:1        3rd Qu.:1      3rd Qu.:1      3rd Qu.:1
#  Max.   :1        Max.   :1      Max.   :1      Max.   :1
#  NA's   :788      NA's   :934    NA's   :782    NA's   :788
#  actor0_prev_revenue  actor1_prev_revenue  actor2_prev_revenue
#  Min.   :         1   Min.   :         1   Min.   :         1
#  1st Qu.:  44264350   1st Qu.:  35114428   1st Qu.:  30857814
#  Median : 151493655   Median : 125586134   Median : 110879513
#  Mean   : 223290867   Mean   : 205206872   Mean   : 195725923
#  3rd Qu.: 311312624   3rd Qu.: 268426634   3rd Qu.: 250649836
#  Max.   :1519557910   Max.   :1519557910   Max.   :1519557910
#  NA's   :2752         NA's   :3201         NA's   :3423
#  director_movies_cnt director_movies_5y_cnt genre_adventure genre_fantasy
#  Min.   : 0          Min.   :0.0            Min.   :0.00    Min.   :0.00
#  1st Qu.: 0          1st Qu.:0.0            1st Qu.:0.00    1st Qu.:0.00
#  Median : 1          Median :0.0            Median :0.00    Median :0.00
#  Mean   : 2          Mean   :0.6            Mean   :0.15    Mean   :0.09
#  3rd Qu.: 3          3rd Qu.:1.0            3rd Qu.:0.00    3rd Qu.:0.00
#  Max.   :29          Max.   :6.0            Max.   :1.00    Max.   :1.00
#
#  genre_animation  genre_drama   genre_horror  genre_action   genre_comedy
#  Min.   :0.00    Min.   :0.0   Min.   :0.0   Min.   :0.00   Min.   :0.00
#  1st Qu.:0.00    1st Qu.:0.0   1st Qu.:0.0   1st Qu.:0.00   1st Qu.:0.00
#  Median :0.00    Median :0.0   Median :0.0   Median :0.00   Median :0.00
#  Mean   :0.05    Mean   :0.5   Mean   :0.1   Mean   :0.24   Mean   :0.35
#  3rd Qu.:0.00    3rd Qu.:1.0   3rd Qu.:0.0   3rd Qu.:0.00   3rd Qu.:1.00
#  Max.   :1.00    Max.   :1.0   Max.   :1.0   Max.   :1.00   Max.   :1.00
#
#  genre_history  genre_western  genre_thriller  genre_crime   genre_documentary
#  Min.   :0.00   Min.   :0.00   Min.   :0.00   Min.   :0.00   Min.   :0.00
#  1st Qu.:0.00   1st Qu.:0.00   1st Qu.:0.00   1st Qu.:0.00   1st Qu.:0.00
#  Median :0.00   Median :0.00   Median :0.00   Median :0.00   Median :0.00
#  Mean   :0.04   Mean   :0.02   Mean   :0.25   Mean   :0.15   Mean   :0.03
#  3rd Qu.:0.00   3rd Qu.:0.00   3rd Qu.:1.00   3rd Qu.:0.00   3rd Qu.:0.00
#  Max.   :1.00   Max.   :1.00   Max.   :1.00   Max.   :1.00   Max.   :1.00
#
#  genre_science_fiction genre_mystery   genre_music   genre_romance
#  Min.   :0.0           Min.   :0.00   Min.   :0.00   Min.   :0.00
#  1st Qu.:0.0           1st Qu.:0.00   1st Qu.:0.00   1st Qu.:0.00
#  Median :0.0           Median :0.00   Median :0.00   Median :0.00
#  Mean   :0.1           Mean   :0.07   Mean   :0.04   Mean   :0.19
#  3rd Qu.:0.0           3rd Qu.:0.00   3rd Qu.:0.00   3rd Qu.:0.00
#  Max.   :1.0           Max.   :1.00   Max.   :1.00   Max.   :1.00
#
#   genre_family    genre_war    genre_foreign    depart_Art depart_Camera
#  Min.   :0.00   Min.   :0.00   Min.   :0.00   Min.   : 0   Min.   : 0
#  1st Qu.:0.00   1st Qu.:0.00   1st Qu.:0.00   1st Qu.: 0   1st Qu.: 0
#  Median :0.00   Median :0.00   Median :0.00   Median : 1   Median : 1
#  Mean   :0.09   Mean   :0.03   Mean   :0.01   Mean   : 3   Mean   : 2
#  3rd Qu.:0.00   3rd Qu.:0.00   3rd Qu.:0.00   3rd Qu.: 3   3rd Qu.: 2
#  Max.   :1.00   Max.   :1.00   Max.   :1.00   Max.   :36   Max.   :24
#                                               NA's   :34   NA's   :34
#   depart_Crew  depart_Custom_Mkup depart_Directing depart_Editing
#  Min.   :  0   Min.   : 0         Min.   : 0       Min.   : 0
#  1st Qu.:  0   1st Qu.: 0         1st Qu.: 1       1st Qu.: 0
#  Median :  0   Median : 1         Median : 1       Median : 1
#  Mean   :  2   Mean   : 2         Mean   : 2       Mean   : 2
#  3rd Qu.:  2   3rd Qu.: 2         3rd Qu.: 2       3rd Qu.: 2
#  Max.   :119   Max.   :33         Max.   :30       Max.   :21
#  NA's   :34    NA's   :34         NA's   :34       NA's   :34
#  depart_Lighting depart_Production  depart_Sound depart_Visual_Effects
#  Min.   : 0      Min.   : 0        Min.   : 0    Min.   : 0
#  1st Qu.: 0      1st Qu.: 1        1st Qu.: 1    1st Qu.: 0
#  Median : 0      Median : 4        Median : 1    Median : 0
#  Mean   : 0      Mean   : 5        Mean   : 3    Mean   : 1
#  3rd Qu.: 0      3rd Qu.: 8        3rd Qu.: 3    3rd Qu.: 0
#  Max.   :18      Max.   :38        Max.   :40    Max.   :89
#  NA's   :34      NA's   :34        NA's   :34    NA's   :34
#  depart_Writing depart_Art_female depart_Camera_female depart_Crew_female
#  Min.   : 0     Min.   :0         Min.   :0            Min.   : 0
#  1st Qu.: 1     1st Qu.:0         1st Qu.:0            1st Qu.: 0
#  Median : 2     Median :0         Median :0            Median : 0
#  Mean   : 2     Mean   :0         Mean   :0            Mean   : 0
#  3rd Qu.: 3     3rd Qu.:0         3rd Qu.:0            3rd Qu.: 0
#  Max.   :23     Max.   :7         Max.   :3            Max.   :10
#  NA's   :34     NA's   :34        NA's   :34           NA's   :34
#  depart_Custom_Mkup_female depart_Directing_female depart_Editing_female
#  Min.   :0                 Min.   :0               Min.   :0
#  1st Qu.:0                 1st Qu.:0               1st Qu.:0
#  Median :0                 Median :0               Median :0
#  Mean   :0                 Mean   :0               Mean   :0
#  3rd Qu.:1                 3rd Qu.:0               3rd Qu.:0
#  Max.   :6                 Max.   :4               Max.   :5
#  NA's   :34                NA's   :34              NA's   :34
#  depart_Lighting_female depart_Production_female depart_Sound_female
#  Min.   :0              Min.   : 0               Min.   :0
#  1st Qu.:0              1st Qu.: 0               1st Qu.:0
#  Median :0              Median : 0               Median :0
#  Mean   :0              Mean   : 1               Mean   :0
#  3rd Qu.:0              3rd Qu.: 2               3rd Qu.:0
#  Max.   :1              Max.   :12               Max.   :6
#  NA's   :34             NA's   :34               NA's   :34
#  depart_Visual_Effects_female depart_Writing_female
#  Min.   :0                    Min.   :0
#  1st Qu.:0                    1st Qu.:0
#  Median :0                    Median :0
#  Mean   :0                    Mean   :0
#  3rd Qu.:0                    3rd Qu.:0
#  Max.   :2                    Max.   :5
#  NA's   :34                   NA's   :34

# %%
rapply(movies_ff,function(x)length(unique(x)))
# Out:
#                     movie_id            original_language
#                         7375                           44
#                 release_date                  runtime_cat
#                         4697                            3
#                      runtime                       budget
#                          168                          704
#                   popularity                      revenue
#                         7371                         2845
#                   sw_lang_en              sw_web_presence
#                            2                            2
#                sw_has_poster                   sw_tagline
#                            2                            2
#                  keyword_cnt                 release_year
#                           46                           99
#                release_month           high_release_month
#                           13                            2
#                  release_day                  seasonality
#                           32                           13
#                sw_collection                producers_cnt
#                            3                           25
#                countries_cnt                      lang_US
#                           12                            2
#                      lang_FR                      lang_RU
#                            2                            2
#                      lang_ES                      lang_JA
#                            2                            2
#                 keywords_cnt            actor0_movies_cnt
#                           46                           61
#         actor0_movies_5y_cnt            actor1_movies_cnt
#                           17                           59
#         actor1_movies_5y_cnt            actor2_movies_cnt
#                           18                           53
#         actor2_movies_5y_cnt             sw_female_actor0
#                           16                            3
#             sw_female_actor1             sw_female_actor2
#                            3                            3
#               sw_male_actor0               sw_male_actor1
#                            3                            3
#               sw_male_actor2          actor0_prev_revenue
#                            3                         1152
#          actor1_prev_revenue          actor2_prev_revenue
#                         1265                         1341
#          director_movies_cnt       director_movies_5y_cnt
#                           30                            7
#              genre_adventure                genre_fantasy
#                            2                            2
#              genre_animation                  genre_drama
#                            2                            2
#                 genre_horror                 genre_action
#                            2                            2
#                 genre_comedy                genre_history
#                            2                            2
#                genre_western               genre_thriller
#                            2                            2
#                  genre_crime            genre_documentary
#                            2                            2
#        genre_science_fiction                genre_mystery
#                            2                            2
#                  genre_music                genre_romance
#                            2                            2
#                 genre_family                    genre_war
#                            2                            2
#                genre_foreign                   depart_Art
#                            2                           35
#                depart_Camera                  depart_Crew
#                           24                           51
#           depart_Custom_Mkup             depart_Directing
#                           28                           24
#               depart_Editing              depart_Lighting
#                           17                           14
#            depart_Production                 depart_Sound
#                           38                           35
#        depart_Visual_Effects               depart_Writing
#                           46                           21
#            depart_Art_female         depart_Camera_female
#                            9                            5
#           depart_Crew_female    depart_Custom_Mkup_female
#                            9                            8
#      depart_Directing_female        depart_Editing_female
#                            6                            6
#       depart_Lighting_female     depart_Production_female
#                            3                           13
#          depart_Sound_female depart_Visual_Effects_female
#                            7                            4
#        depart_Writing_female
#                            7

# %%
#install.packages("pastecs")
library(pastecs)
options(scipen=100)
options(digits=2)
stat.desc(movies_ff[,5:85], basic=TRUE, desc=TRUE, norm=FALSE, p=0.95)
# Out:
# Warning message:
# "package 'pastecs' was built under R version 3.6.2"
#
# Attaching package: 'pastecs'
#
#
# The following objects are masked from 'package:dplyr':
#
#     first, last
#              runtime   budget             popularity   revenue
# nbr.val        7370.00             7375.0  7375.000000              2993.0
# nbr.null         19.00             2012.0     0.000000                 0.0
# nbr.na            5.00                0.0     0.000000              4382.0
# min               0.00                0.0     0.000001                 1.0
# max             338.00        380000000.0   547.488298        1519557910.0
# range           338.00        380000000.0   547.488297        1519557909.0
# sum          794097.00     167166594664.0 62980.853408      200169779760.0
# median          104.00          8000000.0     7.455875          16928137.0
# mean            107.75         22666656.9     8.539777          66879311.6
# SE.mean           0.25           430697.4     0.141787           2516188.3
# CI.mean.0.95      0.49           844290.0     0.277944           4933634.3
# var             458.50 1368064367130662.0   148.264338 18949292507956320.0
# std.dev          21.41         36987354.2    12.176384         137656429.2
# coef.var          0.20                1.6     1.425843                 2.1
#              sw_lang_en sw_web_presence sw_has_poster sw_tagline keyword_cnt
# nbr.val      7375.0000  7375.0000       7375.00000    7375.0000   7375.000
# nbr.null     1039.0000  5012.0000          2.00000    1442.0000    649.000
# nbr.na          0.0000     0.0000          0.00000       0.0000      0.000
# min             0.0000     0.0000          0.00000       0.0000      0.000
# max             1.0000     1.0000          1.00000       1.0000    149.000
# range           1.0000     1.0000          1.00000       1.0000    149.000
# sum          6336.0000  2363.0000       7373.00000    5933.0000  53579.000
# median          1.0000     0.0000          1.00000       1.0000      6.000
# mean            0.8591     0.3204          0.99973       0.8045      7.265
# SE.mean         0.0041     0.0054          0.00019       0.0046      0.073
# CI.mean.0.95    0.0079     0.0107          0.00038       0.0091      0.143
# var             0.1211     0.2178          0.00027       0.1573     39.090
# std.dev         0.3479     0.4667          0.01647       0.3966      6.252
# coef.var        0.4050     1.4565          0.01647       0.4930      0.861
#              release_year  ... depart_Camera_female depart_Crew_female
# nbr.val          7374.0000 ... 7341.0000            7341.0000
# nbr.null            0.0000 ... 7194.0000            6971.0000
# nbr.na              1.0000 ...   34.0000              34.0000
# min              1918.0000 ...    0.0000               0.0000
# max              2017.0000 ...    3.0000              10.0000
# range              99.0000 ...    3.0000              10.0000
# sum          14745625.0000 ...  150.0000             473.0000
# median           2004.0000 ...    0.0000               0.0000
# mean             1999.6779 ...    0.0204               0.0644
# SE.mean             0.1790 ...    0.0017               0.0039
# CI.mean.0.95        0.3510 ...    0.0033               0.0077
# var               236.3624 ...    0.0211               0.1126
# std.dev            15.3741 ...    0.1453               0.3356
# coef.var            0.0077 ...    7.1103               5.2080
#              depart_Custom_Mkup_female depart_Directing_female
# nbr.val      7341.0000                 7341.0000
# nbr.null     5293.0000                 6297.0000
# nbr.na         34.0000                   34.0000
# min             0.0000                    0.0000
# max             6.0000                    4.0000
# range           6.0000                    4.0000
# sum          2595.0000                 1127.0000
# median          0.0000                    0.0000
# mean            0.3535                    0.1535
# SE.mean         0.0076                    0.0046
# CI.mean.0.95    0.0149                    0.0090
# var             0.4245                    0.1556
# std.dev         0.6515                    0.3944
# coef.var        1.8431                    2.5693
#              depart_Editing_female depart_Lighting_female
# nbr.val      7341.0000             7341.00000
# nbr.null     6516.0000             7336.00000
# nbr.na         34.0000               34.00000
# min             0.0000                0.00000
# max             5.0000                1.00000
# range           5.0000                1.00000
# sum           893.0000                5.00000
# median          0.0000                0.00000
# mean            0.1216                0.00068
# SE.mean         0.0042                0.00030
# CI.mean.0.95    0.0082                0.00060
# var             0.1281                0.00068
# std.dev         0.3579                0.02609
# coef.var        2.9424               38.30666
#              depart_Production_female depart_Sound_female
# nbr.val      7341.000                 7341.0000
# nbr.null     3872.000                 6840.0000
# nbr.na         34.000                   34.0000
# min             0.000                    0.0000
# max            12.000                    6.0000
# range          12.000                    6.0000
# sum          6898.000                  581.0000
# median          0.000                    0.0000
# mean            0.940                    0.0791
# SE.mean         0.016                    0.0037
# CI.mean.0.95    0.030                    0.0072
# var             1.767                    0.1001
# std.dev         1.329                    0.3164
# coef.var        1.415                    3.9983
#              depart_Visual_Effects_female depart_Writing_female
# nbr.val      7341.0000                    7341.0000
# nbr.null     7281.0000                    6578.0000
# nbr.na         34.0000                      34.0000
# min             0.0000                       0.0000
# max             2.0000                       5.0000
# range           2.0000                       5.0000
# sum            62.0000                     912.0000
# median          0.0000                       0.0000
# mean            0.0084                       0.1242
# SE.mean         0.0011                       0.0046
# CI.mean.0.95    0.0022                       0.0090
# var             0.0089                       0.1560
# std.dev         0.0944                       0.3949
# coef.var       11.1830                       3.1788

# %% [markdown]
# ###  2.2 Plots

# %%
#Runtime_cat
ggplot(movies_ff, aes(movies_ff$runtime_cat)) +
  geom_bar(fill = "#E69F00",color = "black",size = 0.3, main = "runtime_cat")  + theme_get()
options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Ignoring unknown parameters: main"
# plot without title

# %%
# Runtime
ggplot(movies_ff, aes(x=runtime)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# "Removed 5 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 5 rows containing non-finite values (stat_density)."
# plot without title

# %%
# Budget
ggplot(movies_ff, aes(x=log(budget))) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 5, repr.plot.height = 3)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# "Removed 2012 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 2012 rows containing non-finite values (stat_density)."
# plot without title

# %%
#Original_language
ggplot(movies_ff, aes(movies_ff$original_language)) +
  geom_bar(color = "black", fill = "#E69F00")  + theme_get()
options(repr.plot.width = 20, repr.plot.height = 7)
# Out:
# plot without title

# %%
#Popularity
ggplot(movies_ff, aes(sqrt(log(popularity)))) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
# Out:
# Warning message in sqrt(log(popularity)):
# "NaNs produced"
# Warning message in sqrt(log(popularity)):
# "NaNs produced"
# Warning message in sqrt(log(popularity)):
# "NaNs produced"
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# "Removed 573 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 573 rows containing non-finite values (stat_density)."
# plot without title

# %%
# Revenue
ggplot(movies_ff, aes(x=log(revenue))) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 9)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# "Removed 4382 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 4382 rows containing non-finite values (stat_density)."
# plot without title

# %%
# sw_lang_en
ggplot(movies_ff, aes(movies_ff$sw_lang_en)) + 
    geom_bar(color = "black", fill = "#E69F00")  + 
    theme_get()
   options(repr.plot.width = 7, repr.plot.height = 5)
# Out:
# plot without title

# %%
# sw_web_presence
ggplot(movies_ff, aes(movies_ff$sw_web_presence)) + 
    geom_bar(color = "black", fill = "#E69F00")  + 
    theme_get()
   options(repr.plot.width = 7, repr.plot.height = 5)
# Out:
# plot without title

# %%
# sw_has_poster
ggplot(movies_ff, aes(movies_ff$sw_has_poster)) + 
    geom_bar(color = "black", fill = "#E69F00")  + 
    theme_get()
   options(repr.plot.width = 7, repr.plot.height = 5)
# Out:
# plot without title

# %%
# sw_tagline
ggplot(movies_ff, aes(movies_ff$sw_tagline)) + 
    geom_bar(color = "black", fill = "#E69F00")  + 
    theme_get()
   options(repr.plot.width = 7, repr.plot.height = 5)
# Out:
# plot without title

# %%
# release_year
ggplot(movies_ff, aes(x=movies_ff$release_year)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white",bins = 50)+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 1 rows containing non-finite values (stat_density)."
# plot without title

# %%
# release_month
ggplot(movies_ff, aes(movies_ff$release_month)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 7, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_count)."
# plot without title

# %%
# release_day
ggplot(movies_ff, aes(movies_ff$release_day)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 20, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_count)."
# plot without title

# %%
# seasonality
ggplot(movies_ff, aes(x=movies_ff$seasonality)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white",bins = 50)+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 1 rows containing non-finite values (stat_density)."
# plot without title

# %%
# sw_collection
ggplot(movies_ff, aes(movies_ff$sw_collection)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# producers_cnt
ggplot(movies_ff, aes(movies_ff$producers_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 395 rows containing non-finite values (stat_count)."
# plot without title

# %%
# countries_cnt
ggplot(movies_ff, aes(movies_ff$countries_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# lang_US
ggplot(movies_ff, aes(movies_ff$lang_US)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# lang_FR
ggplot(movies_ff, aes(movies_ff$lang_FR)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# lang_RU
ggplot(movies_ff, aes(movies_ff$lang_RU)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# lang_ES
ggplot(movies_ff, aes(movies_ff$lang_ES)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# lang_JA
ggplot(movies_ff, aes(movies_ff$lang_JA)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# keyword_cnt
ggplot(movies_ff, aes(x=movies_ff$keyword_cnt)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white",bins = 50)+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 5)
# Out:
# plot without title

# %%
# actor0_movies_cnt
ggplot(movies_ff, aes(movies_ff$actor0_movies_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# actor0_movies_5y_cnt
ggplot(movies_ff, aes(movies_ff$actor0_movies_5y_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# actor1_movies_cnt
ggplot(movies_ff, aes(movies_ff$actor1_movies_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 20, repr.plot.height = 5)
# Out:
# plot without title

# %%
# actor1_movies_5y_cnt
ggplot(movies_ff, aes(movies_ff$actor1_movies_5y_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# actor2_movies_cnt
ggplot(movies_ff, aes(movies_ff$actor2_movies_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 20, repr.plot.height = 5)
# Out:
# plot without title

# %%
# actor2_movies_5y_cnt
ggplot(movies_ff, aes(movies_ff$actor2_movies_5y_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# sw_female_actor0
ggplot(movies_ff, aes(movies_ff$sw_female_actor0)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 934 rows containing non-finite values (stat_count)."
# plot without title

# %%
# sw_female_actor1
ggplot(movies_ff, aes(movies_ff$sw_female_actor1)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 782 rows containing non-finite values (stat_count)."
# plot without title

# %%
# sw_female_actor2
ggplot(movies_ff, aes(movies_ff$sw_female_actor2)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 788 rows containing non-finite values (stat_count)."
# plot without title

# %%
# sw_male_actor0
ggplot(movies_ff, aes(movies_ff$sw_male_actor0)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 934 rows containing non-finite values (stat_count)."
# plot without title

# %%
# sw_male_actor1
ggplot(movies_ff, aes(movies_ff$sw_male_actor1)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 782 rows containing non-finite values (stat_count)."
# plot without title

# %%
# sw_male_actor2
ggplot(movies_ff, aes(movies_ff$sw_male_actor2)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 788 rows containing non-finite values (stat_count)."
# plot without title

# %%
# actor0_prev_revenue
ggplot(movies_ff, aes(x=log(movies_ff$actor0_prev_revenue))) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white",bins = 50)+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 2752 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 2752 rows containing non-finite values (stat_density)."
# plot without title

# %%
# actor1_prev_revenue
ggplot(movies_ff, aes(x=log(movies_ff$actor1_prev_revenue))) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white",bins = 50)+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 3201 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 3201 rows containing non-finite values (stat_density)."
# plot without title

# %%
# actor2_prev_revenue
ggplot(movies_ff, aes(x=log(movies_ff$actor2_prev_revenue))) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white",bins = 50)+
 geom_density(alpha=0.2, fill="#E69F00") + theme_get()
options(repr.plot.width = 15, repr.plot.height = 5)
# Out:
# Warning message:
# "Removed 3423 rows containing non-finite values (stat_bin)."
# Warning message:
# "Removed 3423 rows containing non-finite values (stat_density)."
# plot without title

# %%
# director_movies_cnt
ggplot(movies_ff, aes(movies_ff$director_movies_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# director_movies_5y_cnt
ggplot(movies_ff, aes(movies_ff$director_movies_5y_cnt)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get()
   options(repr.plot.width = 8, repr.plot.height = 5)
# Out:
# plot without title

# %%
# Ganres
par(mfrow=c(2,5))

for (i in 45:63) {
    x <- movies_ff[,i]
    print( ggplot(movies_ff, aes(x)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get())
    }
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# Departments
par(mfrow=c(2,5))

for (i in 64:85) {
    x <- movies_ff[,i]
    print( ggplot(movies_ff, aes(x)) + 
    geom_bar(color = "black", fill = "#E69F00")  +
    theme_get())
    }
# Out:
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# Warning message:
# "Removed 34 rows containing non-finite values (stat_count)."
# plot without title
# plot without title

# %%
###  2.3 Correlation matrix

# %%
dbDisconnect(con)
